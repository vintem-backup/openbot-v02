# %%
import psycopg2
import psycopg2.extras
import time
from datetime import datetime
import sys
import subprocess
import requests
import json

# %%
DB_HOST='localhost'
POSTGRES_DB='pg_dev'
POSTGRES_USER='openbot'
POSTGRES_PASSWORD='06Fj@%r7KTXm5+eWn2'

# %%
#Rotina principal

max_requests = 1000 #(provisório)

ciclo_externo = 0
while True:

    print ('Ciclo mais externo = ', ciclo_externo)
    
    #Busca pela tabela de pares
    pairs = db_get_pairs_table
    
    if (len(pairs()) > 0):
        
        print('Tabela de pares encontrada')
            
        for pair in pairs():
            
            if (pair['status'] == 'ON'):
                
                candles_table_name = 'klines_1m_' + str(pair['pair_name'])
                pointer_action = 'SELECT * FROM ' + candles_table_name

                #Verifica se há a tabela de candles:
                try:
                    
                    connection = psycopg2.connect(host=DB_HOST, database=POSTGRES_DB, 
                                                  user=POSTGRES_USER, password=POSTGRES_PASSWORD)
                    
                    pointer = connection.cursor(cursor_factory=psycopg2.extras.DictCursor)

                    pointer.execute(pointer_action)

                    #Adquire os dados históricos, caso não existam:
                    if (pair['historical'] == 'absent'):

                        #Historical update
                        pair = str(pair['pair_name'])

                        #pid = subprocess.Popen([sys.executable, "teste.py", pair, max_requests])

                        pid = get_historical_data(pair, max_requests)

                        print('Par: ', pair, ' Historico ausente, completar')

                    elif (pair['historical'] == 'full'):
                        
                        print('massa de dados completa')

                        candles = pointer.fetchall()
                        #latest_candle = candles[len(candles)]

                        #Current update
                
                #Se não existe, a cria:
                except (Exception, psycopg2.Error) as error:
                    
                    print('tabela inexistente, criando-a')
                    print(' ')

                    print(error)

                    pointer.execute("ROLLBACK")

                    pointer_action = "CREATE TABLE " + candles_table_name + ''' 
                    (open_time timestamp PRIMARY KEY, open numeric, high numeric, low numeric, close numeric,
                    volume numeric, quote_asset_volume numeric, number_of_trades integer, 
                    taker_buy_base_asset_volume numeric, taker_buy_quote_asset_volume numeric);
                    '''
                    pointer.execute(pointer_action)
                    
                finally:
                    
                    if (connection):
                        pointer.close()
                        connection.close()
        
        ciclo_externo+=1
        print('dormindo 1 min')
        time.sleep(60) #Ajeitar para acordar poucos segundos após fechamento do próximo candle
        
    #Descansa 5min se não houver a tabela de pares
    else:
        
        print('Tabela de pares ausente ausente, dormindo 5min')
        time.sleep(300)
# Out:
# Ciclo mais externo =  0
# Tabela de pares encontrada
# tabela inexistente, criando-a
#
# relation "klines_1m_btcusdt" does not exist
# LINE 1: SELECT * FROM klines_1m_BTCUSDT
#                       ^
#
# dormindo 1 min
# Ciclo mais externo =  1
# Tabela de pares encontrada
# Atualizando par  BTCUSDT  para buiding. Status =  done
#
# entrada ok, na tentativa:  0
#
# Oldest request gravada no banco
#
# New-kline gravada no banco no ciclo:  0
# Número de requests:  2
# New-kline gravada no banco no ciclo:  1
# Número de requests:  3
# New-kline gravada no banco no ciclo:  2
# Número de requests:  4
# New-kline gravada no banco no ciclo:  3
# Número de requests:  5
# New-kline gravada no banco no ciclo:  4
# Número de requests:  6
# New-kline gravada no banco no ciclo:  5
# Número de requests:  7
# New-kline gravada no banco no ciclo:  6
# Número de requests:  8
# New-kline gravada no banco no ciclo:  7
# Número de requests:  9
# New-kline gravada no banco no ciclo:  8
# Número de requests:  10
# New-kline gravada no banco no ciclo:  9
# Número de requests:  11
# New-kline gravada no banco no ciclo:  10
# Número de requests:  12
# New-kline gravada no banco no ciclo:  11
# Número de requests:  13
# New-kline gravada no banco no ciclo:  12
# Número de requests:  14
# New-kline gravada no banco no ciclo:  13
# Número de requests:  15
# New-kline gravada no banco no ciclo:  14
# Número de requests:  16
# New-kline gravada no banco no ciclo:  15
# Número de requests:  17
# New-kline gravada no banco no ciclo:  16
# Número de requests:  18
# New-kline gravada no banco no ciclo:  17
# Número de requests:  19
# New-kline gravada no banco no ciclo:  18
# Número de requests:  20
# New-kline gravada no banco no ciclo:  19
# Número de requests:  21
# New-kline gravada no banco no ciclo:  20
# Número de requests:  22
# New-kline gravada no banco no ciclo:  21
# Número de requests:  23
# New-kline gravada no banco no ciclo:  22
# Número de requests:  24
# New-kline gravada no banco no ciclo:  23
# Número de requests:  25
# New-kline gravada no banco no ciclo:  24
# Número de requests:  26
# New-kline gravada no banco no ciclo:  25
# Número de requests:  27
# New-kline gravada no banco no ciclo:  26
# Número de requests:  28
# New-kline gravada no banco no ciclo:  27
# Número de requests:  29
# New-kline gravada no banco no ciclo:  28
# Número de requests:  30
# New-kline gravada no banco no ciclo:  29
# Número de requests:  31
# New-kline gravada no banco no ciclo:  30
# Número de requests:  32
# New-kline gravada no banco no ciclo:  31
# Número de requests:  33
# New-kline gravada no banco no ciclo:  32
# Número de requests:  34
# New-kline gravada no banco no ciclo:  33
# Número de requests:  35
# New-kline gravada no banco no ciclo:  34
# Número de requests:  36
# New-kline gravada no banco no ciclo:  35
# Número de requests:  37
# New-kline gravada no banco no ciclo:  36
# Número de requests:  38
# New-kline gravada no banco no ciclo:  37
# Número de requests:  39
# New-kline gravada no banco no ciclo:  38
# Número de requests:  40
# New-kline gravada no banco no ciclo:  39
# Número de requests:  41
# New-kline gravada no banco no ciclo:  40
# Número de requests:  42
# New-kline gravada no banco no ciclo:  41
# Número de requests:  43
# New-kline gravada no banco no ciclo:  42
# Número de requests:  44
# New-kline gravada no banco no ciclo:  43
# Número de requests:  45
# New-kline gravada no banco no ciclo:  44
# Número de requests:  46
# New-kline gravada no banco no ciclo:  45
# Número de requests:  47
# New-kline gravada no banco no ciclo:  46
# Número de requests:  48
# New-kline gravada no banco no ciclo:  47
# Número de requests:  49
# New-kline gravada no banco no ciclo:  48
# Número de requests:  50
# New-kline gravada no banco no ciclo:  49
# Número de requests:  51
# New-kline gravada no banco no ciclo:  50
# Número de requests:  52
# New-kline gravada no banco no ciclo:  51
# Número de requests:  53
# New-kline gravada no banco no ciclo:  52
# Número de requests:  54
# New-kline gravada no banco no ciclo:  53
# Número de requests:  55
# New-kline gravada no banco no ciclo:  54
# Número de requests:  56
# New-kline gravada no banco no ciclo:  55
# Número de requests:  57
# New-kline gravada no banco no ciclo:  56
# Número de requests:  58
# New-kline gravada no banco no ciclo:  57
# Número de requests:  59
# New-kline gravada no banco no ciclo:  58
# Número de requests:  60
# New-kline gravada no banco no ciclo:  59
# Número de requests:  61
# New-kline gravada no banco no ciclo:  60
# Número de requests:  62
# New-kline gravada no banco no ciclo:  61
# Número de requests:  63
# New-kline gravada no banco no ciclo:  62
# Número de requests:  64
# New-kline gravada no banco no ciclo:  63
# Número de requests:  65
# New-kline gravada no banco no ciclo:  64
# Número de requests:  66
# New-kline gravada no banco no ciclo:  65
# Número de requests:  67
# New-kline gravada no banco no ciclo:  66
# Número de requests:  68
# New-kline gravada no banco no ciclo:  67
# Número de requests:  69
# New-kline gravada no banco no ciclo:  68
# Número de requests:  70
# New-kline gravada no banco no ciclo:  69
# Número de requests:  71
# New-kline gravada no banco no ciclo:  70
# Número de requests:  72
# New-kline gravada no banco no ciclo:  71
# Número de requests:  73
# New-kline gravada no banco no ciclo:  72
# Número de requests:  74
# New-kline gravada no banco no ciclo:  73
# Número de requests:  75
# New-kline gravada no banco no ciclo:  74
# Número de requests:  76
# New-kline gravada no banco no ciclo:  75
# Número de requests:  77
# New-kline gravada no banco no ciclo:  76
# Número de requests:  78
# New-kline gravada no banco no ciclo:  77
# Número de requests:  79
# New-kline gravada no banco no ciclo:  78
# Número de requests:  80
# New-kline gravada no banco no ciclo:  79
# Número de requests:  81
# New-kline gravada no banco no ciclo:  80
# Número de requests:  82
# New-kline gravada no banco no ciclo:  81
# Número de requests:  83
# New-kline gravada no banco no ciclo:  82
# Número de requests:  84
# New-kline gravada no banco no ciclo:  83
# Número de requests:  85
# New-kline gravada no banco no ciclo:  84
# Número de requests:  86
# New-kline gravada no banco no ciclo:  85
# Número de requests:  87
# New-kline gravada no banco no ciclo:  86
# Número de requests:  88
# New-kline gravada no banco no ciclo:  87
# Número de requests:  89
# New-kline gravada no banco no ciclo:  88
# Número de requests:  90
# New-kline gravada no banco no ciclo:  89
# Número de requests:  91
# New-kline gravada no banco no ciclo:  90
# Número de requests:  92
# New-kline gravada no banco no ciclo:  91
# Número de requests:  93
# New-kline gravada no banco no ciclo:  92
# Número de requests:  94
# New-kline gravada no banco no ciclo:  93
# Número de requests:  95
# New-kline gravada no banco no ciclo:  94
# Número de requests:  96
# New-kline gravada no banco no ciclo:  95
# Número de requests:  97
# New-kline gravada no banco no ciclo:  96
# Número de requests:  98
# New-kline gravada no banco no ciclo:  97
# Número de requests:  99
# New-kline gravada no banco no ciclo:  98
# Número de requests:  100
# New-kline gravada no banco no ciclo:  99
# Número de requests:  101
# New-kline gravada no banco no ciclo:  100
# Número de requests:  102
# New-kline gravada no banco no ciclo:  101
# Número de requests:  103
# New-kline gravada no banco no ciclo:  102
# Número de requests:  104
# New-kline gravada no banco no ciclo:  103
# Número de requests:  105
# New-kline gravada no banco no ciclo:  104
# Número de requests:  106
# New-kline gravada no banco no ciclo:  105
# Número de requests:  107
# New-kline gravada no banco no ciclo:  106
# Número de requests:  108
# New-kline gravada no banco no ciclo:  107
# Número de requests:  109
# New-kline gravada no banco no ciclo:  108
# Número de requests:  110
# New-kline gravada no banco no ciclo:  109
# Número de requests:  111
# New-kline gravada no banco no ciclo:  110
# Número de requests:  112
# New-kline gravada no banco no ciclo:  111
# Número de requests:  113
# New-kline gravada no banco no ciclo:  112
# Número de requests:  114
# New-kline gravada no banco no ciclo:  113
# Número de requests:  115
# New-kline gravada no banco no ciclo:  114
# Número de requests:  116
# New-kline gravada no banco no ciclo:  115
# Número de requests:  117
# New-kline gravada no banco no ciclo:  116
# Número de requests:  118
# New-kline gravada no banco no ciclo:  117
# Número de requests:  119
# New-kline gravada no banco no ciclo:  118
# Número de requests:  120
# New-kline gravada no banco no ciclo:  119
# Número de requests:  121
# New-kline gravada no banco no ciclo:  120
# Número de requests:  122
# New-kline gravada no banco no ciclo:  121
# Número de requests:  123
# New-kline gravada no banco no ciclo:  122
# Número de requests:  124
# New-kline gravada no banco no ciclo:  123
# Número de requests:  125
# New-kline gravada no banco no ciclo:  124
# Número de requests:  126
# New-kline gravada no banco no ciclo:  125
# Número de requests:  127
# New-kline gravada no banco no ciclo:  126
# Número de requests:  128
# New-kline gravada no banco no ciclo:  127
# Número de requests:  129
# New-kline gravada no banco no ciclo:  128
# Número de requests:  130
# New-kline gravada no banco no ciclo:  129
# Número de requests:  131
# New-kline gravada no banco no ciclo:  130
# Número de requests:  132
# New-kline gravada no banco no ciclo:  131
# Número de requests:  133
# New-kline gravada no banco no ciclo:  132
# Número de requests:  134
# New-kline gravada no banco no ciclo:  133
# Número de requests:  135
# New-kline gravada no banco no ciclo:  134
# Número de requests:  136
# New-kline gravada no banco no ciclo:  135
# Número de requests:  137
# New-kline gravada no banco no ciclo:  136
# Número de requests:  138
# New-kline gravada no banco no ciclo:  137
# Número de requests:  139
# New-kline gravada no banco no ciclo:  138
# Número de requests:  140
# New-kline gravada no banco no ciclo:  139
# Número de requests:  141
# New-kline gravada no banco no ciclo:  140
# Número de requests:  142
# New-kline gravada no banco no ciclo:  141
# Número de requests:  143
# New-kline gravada no banco no ciclo:  142
# Número de requests:  144
# New-kline gravada no banco no ciclo:  143
# Número de requests:  145
# New-kline gravada no banco no ciclo:  144
# Número de requests:  146
# New-kline gravada no banco no ciclo:  145
# Número de requests:  147
# New-kline gravada no banco no ciclo:  146
# Número de requests:  148
# New-kline gravada no banco no ciclo:  147
# Número de requests:  149
# New-kline gravada no banco no ciclo:  148
# Número de requests:  150
# New-kline gravada no banco no ciclo:  149
# Número de requests:  151
# New-kline gravada no banco no ciclo:  150
# Número de requests:  152
# New-kline gravada no banco no ciclo:  151
# Número de requests:  153
# New-kline gravada no banco no ciclo:  152
# Número de requests:  154
# New-kline gravada no banco no ciclo:  153
# Número de requests:  155
# New-kline gravada no banco no ciclo:  154
# Número de requests:  156
# New-kline gravada no banco no ciclo:  155
# Número de requests:  157
# New-kline gravada no banco no ciclo:  156
# Número de requests:  158
# New-kline gravada no banco no ciclo:  157
# Número de requests:  159
# New-kline gravada no banco no ciclo:  158
# Número de requests:  160
# New-kline gravada no banco no ciclo:  159
# Número de requests:  161
# New-kline gravada no banco no ciclo:  160
# Número de requests:  162
# New-kline gravada no banco no ciclo:  161
# Número de requests:  163
# New-kline gravada no banco no ciclo:  162
# Número de requests:  164
# New-kline gravada no banco no ciclo:  163
# Número de requests:  165
# New-kline gravada no banco no ciclo:  164
# Número de requests:  166
# New-kline gravada no banco no ciclo:  165
# Número de requests:  167
# New-kline gravada no banco no ciclo:  166
# Número de requests:  168
# New-kline gravada no banco no ciclo:  167
# Número de requests:  169
# New-kline gravada no banco no ciclo:  168
# Número de requests:  170
# New-kline gravada no banco no ciclo:  169
# Número de requests:  171
# New-kline gravada no banco no ciclo:  170
# Número de requests:  172
# New-kline gravada no banco no ciclo:  171
# Número de requests:  173
# New-kline gravada no banco no ciclo:  172
# Número de requests:  174
# New-kline gravada no banco no ciclo:  173
# Número de requests:  175
# New-kline gravada no banco no ciclo:  174
# Número de requests:  176
# New-kline gravada no banco no ciclo:  175
# Número de requests:  177
# New-kline gravada no banco no ciclo:  176
# Número de requests:  178
# New-kline gravada no banco no ciclo:  177
# Número de requests:  179
# New-kline gravada no banco no ciclo:  178
# Número de requests:  180
# New-kline gravada no banco no ciclo:  179
# Número de requests:  181
# New-kline gravada no banco no ciclo:  180
# Número de requests:  182
# New-kline gravada no banco no ciclo:  181
# Número de requests:  183
# New-kline gravada no banco no ciclo:  182
# Número de requests:  184
# New-kline gravada no banco no ciclo:  183
# Número de requests:  185
# New-kline gravada no banco no ciclo:  184
# Número de requests:  186
# New-kline gravada no banco no ciclo:  185
# Número de requests:  187
# New-kline gravada no banco no ciclo:  186
# Número de requests:  188
# New-kline gravada no banco no ciclo:  187
# Número de requests:  189
# New-kline gravada no banco no ciclo:  188
# Número de requests:  190
# New-kline gravada no banco no ciclo:  189
# Número de requests:  191
# New-kline gravada no banco no ciclo:  190
# Número de requests:  192
# New-kline gravada no banco no ciclo:  191
# Número de requests:  193
# New-kline gravada no banco no ciclo:  192
# Número de requests:  194
# New-kline gravada no banco no ciclo:  193
# Número de requests:  195
# New-kline gravada no banco no ciclo:  194
# Número de requests:  196
# New-kline gravada no banco no ciclo:  195
# Número de requests:  197
# New-kline gravada no banco no ciclo:  196
# Número de requests:  198
# New-kline gravada no banco no ciclo:  197
# Número de requests:  199
# New-kline gravada no banco no ciclo:  198
# Número de requests:  200
# New-kline gravada no banco no ciclo:  199
# Número de requests:  201
# New-kline gravada no banco no ciclo:  200
# Número de requests:  202
# New-kline gravada no banco no ciclo:  201
# Número de requests:  203
# New-kline gravada no banco no ciclo:  202
# Número de requests:  204
# New-kline gravada no banco no ciclo:  203
# Número de requests:  205
# New-kline gravada no banco no ciclo:  204
# Número de requests:  206
# New-kline gravada no banco no ciclo:  205
# Número de requests:  207
# New-kline gravada no banco no ciclo:  206
# Número de requests:  208
# New-kline gravada no banco no ciclo:  207
# Número de requests:  209
# New-kline gravada no banco no ciclo:  208
# Número de requests:  210
# New-kline gravada no banco no ciclo:  209
# Número de requests:  211
# New-kline gravada no banco no ciclo:  210
# Número de requests:  212
# New-kline gravada no banco no ciclo:  211
# Número de requests:  213
# New-kline gravada no banco no ciclo:  212
# Número de requests:  214
# New-kline gravada no banco no ciclo:  213
# Número de requests:  215
# New-kline gravada no banco no ciclo:  214
# Número de requests:  216
# New-kline gravada no banco no ciclo:  215
# Número de requests:  217
# New-kline gravada no banco no ciclo:  216
# Número de requests:  218
# New-kline gravada no banco no ciclo:  217
# Número de requests:  219
# New-kline gravada no banco no ciclo:  218
# Número de requests:  220
# New-kline gravada no banco no ciclo:  219
# Número de requests:  221
# New-kline gravada no banco no ciclo:  220
# Número de requests:  222
# New-kline gravada no banco no ciclo:  221
# Número de requests:  223
# New-kline gravada no banco no ciclo:  222
# Número de requests:  224
# New-kline gravada no banco no ciclo:  223
# Número de requests:  225
# New-kline gravada no banco no ciclo:  224
# Número de requests:  226
# New-kline gravada no banco no ciclo:  225
# Número de requests:  227
# New-kline gravada no banco no ciclo:  226
# Número de requests:  228
# New-kline gravada no banco no ciclo:  227
# Número de requests:  229
# New-kline gravada no banco no ciclo:  228
# Número de requests:  230
# New-kline gravada no banco no ciclo:  229
# Número de requests:  231
# New-kline gravada no banco no ciclo:  230
# Número de requests:  232
# New-kline gravada no banco no ciclo:  231
# Número de requests:  233
# New-kline gravada no banco no ciclo:  232
# Número de requests:  234
# New-kline gravada no banco no ciclo:  233
# Número de requests:  235
# New-kline gravada no banco no ciclo:  234
# Número de requests:  236
# New-kline gravada no banco no ciclo:  235
# Número de requests:  237
# New-kline gravada no banco no ciclo:  236
# Número de requests:  238
# New-kline gravada no banco no ciclo:  237
# Número de requests:  239
# New-kline gravada no banco no ciclo:  238
# Número de requests:  240
# New-kline gravada no banco no ciclo:  239
# Número de requests:  241
# New-kline gravada no banco no ciclo:  240
# Número de requests:  242
# New-kline gravada no banco no ciclo:  241
# Número de requests:  243
# New-kline gravada no banco no ciclo:  242
# Número de requests:  244
# New-kline gravada no banco no ciclo:  243
# Número de requests:  245
# New-kline gravada no banco no ciclo:  244
# Número de requests:  246
# New-kline gravada no banco no ciclo:  245
# Número de requests:  247
# New-kline gravada no banco no ciclo:  246
# Número de requests:  248
# New-kline gravada no banco no ciclo:  247
# Número de requests:  249
# New-kline gravada no banco no ciclo:  248
# Número de requests:  250
# New-kline gravada no banco no ciclo:  249
# Número de requests:  251
# New-kline gravada no banco no ciclo:  250
# Número de requests:  252
# New-kline gravada no banco no ciclo:  251
# Número de requests:  253
# New-kline gravada no banco no ciclo:  252
# Número de requests:  254
# New-kline gravada no banco no ciclo:  253
# Número de requests:  255
# New-kline gravada no banco no ciclo:  254
# Número de requests:  256
# New-kline gravada no banco no ciclo:  255
# Número de requests:  257
# New-kline gravada no banco no ciclo:  256
# Número de requests:  258
# New-kline gravada no banco no ciclo:  257
# Número de requests:  259
# New-kline gravada no banco no ciclo:  258
# Número de requests:  260
# New-kline gravada no banco no ciclo:  259
# Número de requests:  261
# New-kline gravada no banco no ciclo:  260
# Número de requests:  262
# New-kline gravada no banco no ciclo:  261
# Número de requests:  263
# New-kline gravada no banco no ciclo:  262
# Número de requests:  264
# New-kline gravada no banco no ciclo:  263
# Número de requests:  265
# New-kline gravada no banco no ciclo:  264
# Número de requests:  266
# New-kline gravada no banco no ciclo:  265
# Número de requests:  267
# New-kline gravada no banco no ciclo:  266
# Número de requests:  268
# New-kline gravada no banco no ciclo:  267
# Número de requests:  269
# New-kline gravada no banco no ciclo:  268
# Número de requests:  270
# New-kline gravada no banco no ciclo:  269
# Número de requests:  271
# New-kline gravada no banco no ciclo:  270
# Número de requests:  272
# New-kline gravada no banco no ciclo:  271
# Número de requests:  273
# New-kline gravada no banco no ciclo:  272
# Número de requests:  274
# New-kline gravada no banco no ciclo:  273
# Número de requests:  275
# New-kline gravada no banco no ciclo:  274
# Número de requests:  276
# New-kline gravada no banco no ciclo:  275
# Número de requests:  277
# New-kline gravada no banco no ciclo:  276
# Número de requests:  278
# New-kline gravada no banco no ciclo:  277
# Número de requests:  279
# New-kline gravada no banco no ciclo:  278
# Número de requests:  280
# New-kline gravada no banco no ciclo:  279
# Número de requests:  281
# New-kline gravada no banco no ciclo:  280
# Número de requests:  282
# New-kline gravada no banco no ciclo:  281
# Número de requests:  283
# New-kline gravada no banco no ciclo:  282
# Número de requests:  284
# New-kline gravada no banco no ciclo:  283
# Número de requests:  285
# New-kline gravada no banco no ciclo:  284
# Número de requests:  286
# New-kline gravada no banco no ciclo:  285
# Número de requests:  287
# New-kline gravada no banco no ciclo:  286
# Número de requests:  288
# New-kline gravada no banco no ciclo:  287
# Número de requests:  289
# New-kline gravada no banco no ciclo:  288
# Número de requests:  290
# New-kline gravada no banco no ciclo:  289
# Número de requests:  291
# New-kline gravada no banco no ciclo:  290
# Número de requests:  292
# New-kline gravada no banco no ciclo:  291
# Número de requests:  293
# New-kline gravada no banco no ciclo:  292
# Número de requests:  294
# New-kline gravada no banco no ciclo:  293
# Número de requests:  295
# New-kline gravada no banco no ciclo:  294
# Número de requests:  296
# New-kline gravada no banco no ciclo:  295
# Número de requests:  297
# New-kline gravada no banco no ciclo:  296
# Número de requests:  298
# New-kline gravada no banco no ciclo:  297
# Número de requests:  299
# New-kline gravada no banco no ciclo:  298
# Número de requests:  300
# New-kline gravada no banco no ciclo:  299
# Número de requests:  301
# New-kline gravada no banco no ciclo:  300
# Número de requests:  302
# New-kline gravada no banco no ciclo:  301
# Número de requests:  303
# New-kline gravada no banco no ciclo:  302
# Número de requests:  304
# New-kline gravada no banco no ciclo:  303
# Número de requests:  305
# New-kline gravada no banco no ciclo:  304
# Número de requests:  306
# New-kline gravada no banco no ciclo:  305
# Número de requests:  307
# New-kline gravada no banco no ciclo:  306
# Número de requests:  308
# New-kline gravada no banco no ciclo:  307
# Número de requests:  309
# New-kline gravada no banco no ciclo:  308
# Número de requests:  310
# New-kline gravada no banco no ciclo:  309
# Número de requests:  311
# New-kline gravada no banco no ciclo:  310
# Número de requests:  312
# New-kline gravada no banco no ciclo:  311
# Número de requests:  313
# New-kline gravada no banco no ciclo:  312
# Número de requests:  314
# New-kline gravada no banco no ciclo:  313
# Número de requests:  315
# New-kline gravada no banco no ciclo:  314
# Número de requests:  316
# New-kline gravada no banco no ciclo:  315
# Número de requests:  317
# New-kline gravada no banco no ciclo:  316
# Número de requests:  318
# New-kline gravada no banco no ciclo:  317
# Número de requests:  319
# New-kline gravada no banco no ciclo:  318
# Número de requests:  320
# New-kline gravada no banco no ciclo:  319
# Número de requests:  321
# New-kline gravada no banco no ciclo:  320
# Número de requests:  322
# New-kline gravada no banco no ciclo:  321
# Número de requests:  323
# New-kline gravada no banco no ciclo:  322
# Número de requests:  324
# New-kline gravada no banco no ciclo:  323
# Número de requests:  325
# New-kline gravada no banco no ciclo:  324
# Número de requests:  326
# New-kline gravada no banco no ciclo:  325
# Número de requests:  327
# New-kline gravada no banco no ciclo:  326
# Número de requests:  328
# New-kline gravada no banco no ciclo:  327
# Número de requests:  329
# New-kline gravada no banco no ciclo:  328
# Número de requests:  330
# New-kline gravada no banco no ciclo:  329
# Número de requests:  331
# New-kline gravada no banco no ciclo:  330
# Número de requests:  332
# New-kline gravada no banco no ciclo:  331
# Número de requests:  333
# New-kline gravada no banco no ciclo:  332
# Número de requests:  334
# New-kline gravada no banco no ciclo:  333
# Número de requests:  335
# New-kline gravada no banco no ciclo:  334
# Número de requests:  336
# New-kline gravada no banco no ciclo:  335
# Número de requests:  337
# New-kline gravada no banco no ciclo:  336
# Número de requests:  338
# New-kline gravada no banco no ciclo:  337
# Número de requests:  339
# New-kline gravada no banco no ciclo:  338
# Número de requests:  340
# New-kline gravada no banco no ciclo:  339
# Número de requests:  341
# New-kline gravada no banco no ciclo:  340
# Número de requests:  342
# New-kline gravada no banco no ciclo:  341
# Número de requests:  343
# New-kline gravada no banco no ciclo:  342
# Número de requests:  344
# New-kline gravada no banco no ciclo:  343
# Número de requests:  345
# New-kline gravada no banco no ciclo:  344
# Número de requests:  346
# New-kline gravada no banco no ciclo:  345
# Número de requests:  347
# New-kline gravada no banco no ciclo:  346
# Número de requests:  348
# New-kline gravada no banco no ciclo:  347
# Número de requests:  349
# New-kline gravada no banco no ciclo:  348
# Número de requests:  350
# New-kline gravada no banco no ciclo:  349
# Número de requests:  351
# New-kline gravada no banco no ciclo:  350
# Número de requests:  352
# New-kline gravada no banco no ciclo:  351
# Número de requests:  353
# New-kline gravada no banco no ciclo:  352
# Número de requests:  354
# New-kline gravada no banco no ciclo:  353
# Número de requests:  355
# New-kline gravada no banco no ciclo:  354
# Número de requests:  356
# New-kline gravada no banco no ciclo:  355
# Número de requests:  357
# New-kline gravada no banco no ciclo:  356
# Número de requests:  358
# New-kline gravada no banco no ciclo:  357
# Número de requests:  359
# New-kline gravada no banco no ciclo:  358
# Número de requests:  360
# New-kline gravada no banco no ciclo:  359
# Número de requests:  361
# New-kline gravada no banco no ciclo:  360
# Número de requests:  362
# New-kline gravada no banco no ciclo:  361
# Número de requests:  363
# New-kline gravada no banco no ciclo:  362
# Número de requests:  364
# New-kline gravada no banco no ciclo:  363
# Número de requests:  365
# New-kline gravada no banco no ciclo:  364
# Número de requests:  366
# New-kline gravada no banco no ciclo:  365
# Número de requests:  367
# New-kline gravada no banco no ciclo:  366
# Número de requests:  368
# New-kline gravada no banco no ciclo:  367
# Número de requests:  369
# New-kline gravada no banco no ciclo:  368
# Número de requests:  370
# New-kline gravada no banco no ciclo:  369
# Número de requests:  371
# New-kline gravada no banco no ciclo:  370
# Número de requests:  372
# New-kline gravada no banco no ciclo:  371
# Número de requests:  373
# New-kline gravada no banco no ciclo:  372
# Número de requests:  374
# New-kline gravada no banco no ciclo:  373
# Número de requests:  375
# New-kline gravada no banco no ciclo:  374
# Número de requests:  376
# New-kline gravada no banco no ciclo:  375
# Número de requests:  377
# New-kline gravada no banco no ciclo:  376
# Número de requests:  378
# New-kline gravada no banco no ciclo:  377
# Número de requests:  379
# New-kline gravada no banco no ciclo:  378
# Número de requests:  380
# New-kline gravada no banco no ciclo:  379
# Número de requests:  381
# New-kline gravada no banco no ciclo:  380
# Número de requests:  382
# New-kline gravada no banco no ciclo:  381
# Número de requests:  383
# New-kline gravada no banco no ciclo:  382
# Número de requests:  384
# New-kline gravada no banco no ciclo:  383
# Número de requests:  385
# New-kline gravada no banco no ciclo:  384
# Número de requests:  386
# New-kline gravada no banco no ciclo:  385
# Número de requests:  387
# New-kline gravada no banco no ciclo:  386
# Número de requests:  388
# New-kline gravada no banco no ciclo:  387
# Número de requests:  389
# New-kline gravada no banco no ciclo:  388
# Número de requests:  390
# New-kline gravada no banco no ciclo:  389
# Número de requests:  391
# New-kline gravada no banco no ciclo:  390
# Número de requests:  392
# New-kline gravada no banco no ciclo:  391
# Número de requests:  393
# New-kline gravada no banco no ciclo:  392
# Número de requests:  394
# New-kline gravada no banco no ciclo:  393
# Número de requests:  395
# New-kline gravada no banco no ciclo:  394
# Número de requests:  396
# New-kline gravada no banco no ciclo:  395
# Número de requests:  397
# New-kline gravada no banco no ciclo:  396
# Número de requests:  398
# New-kline gravada no banco no ciclo:  397
# Número de requests:  399
# New-kline gravada no banco no ciclo:  398
# Número de requests:  400
# New-kline gravada no banco no ciclo:  399
# Número de requests:  401
# New-kline gravada no banco no ciclo:  400
# Número de requests:  402
# New-kline gravada no banco no ciclo:  401
# Número de requests:  403
# New-kline gravada no banco no ciclo:  402
# Número de requests:  404
# New-kline gravada no banco no ciclo:  403
# Número de requests:  405
# New-kline gravada no banco no ciclo:  404
# Número de requests:  406
# New-kline gravada no banco no ciclo:  405
# Número de requests:  407
# New-kline gravada no banco no ciclo:  406
# Número de requests:  408
# New-kline gravada no banco no ciclo:  407
# Número de requests:  409
# New-kline gravada no banco no ciclo:  408
# Número de requests:  410
# New-kline gravada no banco no ciclo:  409
# Número de requests:  411
# New-kline gravada no banco no ciclo:  410
# Número de requests:  412
# New-kline gravada no banco no ciclo:  411
# Número de requests:  413
# New-kline gravada no banco no ciclo:  412
# Número de requests:  414
# New-kline gravada no banco no ciclo:  413
# Número de requests:  415
# New-kline gravada no banco no ciclo:  414
# Número de requests:  416
# New-kline gravada no banco no ciclo:  415
# Número de requests:  417
# New-kline gravada no banco no ciclo:  416
# Número de requests:  418
# New-kline gravada no banco no ciclo:  417
# Número de requests:  419
# New-kline gravada no banco no ciclo:  418
# Número de requests:  420
# New-kline gravada no banco no ciclo:  419
# Número de requests:  421
# New-kline gravada no banco no ciclo:  420
# Número de requests:  422
# New-kline gravada no banco no ciclo:  421
# Número de requests:  423
# New-kline gravada no banco no ciclo:  422
# Número de requests:  424
# New-kline gravada no banco no ciclo:  423
# Número de requests:  425
# New-kline gravada no banco no ciclo:  424
# Número de requests:  426
# New-kline gravada no banco no ciclo:  425
# Número de requests:  427
# New-kline gravada no banco no ciclo:  426
# Número de requests:  428
# New-kline gravada no banco no ciclo:  427
# Número de requests:  429
# New-kline gravada no banco no ciclo:  428
# Número de requests:  430
# New-kline gravada no banco no ciclo:  429
# Número de requests:  431
# New-kline gravada no banco no ciclo:  430
# Número de requests:  432
# New-kline gravada no banco no ciclo:  431
# Número de requests:  433
# New-kline gravada no banco no ciclo:  432
# Número de requests:  434
# New-kline gravada no banco no ciclo:  433
# Número de requests:  435
# New-kline gravada no banco no ciclo:  434
# Número de requests:  436
# New-kline gravada no banco no ciclo:  435
# Número de requests:  437
# New-kline gravada no banco no ciclo:  436
# Número de requests:  438
# New-kline gravada no banco no ciclo:  437
# Número de requests:  439
# New-kline gravada no banco no ciclo:  438
# Número de requests:  440
# New-kline gravada no banco no ciclo:  439
# Número de requests:  441
# New-kline gravada no banco no ciclo:  440
# Número de requests:  442
# New-kline gravada no banco no ciclo:  441
# Número de requests:  443
# New-kline gravada no banco no ciclo:  442
# Número de requests:  444
# New-kline gravada no banco no ciclo:  443
# Número de requests:  445
# New-kline gravada no banco no ciclo:  444
# Número de requests:  446
# New-kline gravada no banco no ciclo:  445
# Número de requests:  447
# New-kline gravada no banco no ciclo:  446
# Número de requests:  448
# New-kline gravada no banco no ciclo:  447
# Número de requests:  449
# New-kline gravada no banco no ciclo:  448
# Número de requests:  450
# New-kline gravada no banco no ciclo:  449
# Número de requests:  451
# New-kline gravada no banco no ciclo:  450
# Número de requests:  452
# New-kline gravada no banco no ciclo:  451
# Número de requests:  453
# New-kline gravada no banco no ciclo:  452
# Número de requests:  454
# New-kline gravada no banco no ciclo:  453
# Número de requests:  455
# New-kline gravada no banco no ciclo:  454
# Número de requests:  456
# New-kline gravada no banco no ciclo:  455
# Número de requests:  457
# New-kline gravada no banco no ciclo:  456
# Número de requests:  458
# New-kline gravada no banco no ciclo:  457
# Número de requests:  459
# New-kline gravada no banco no ciclo:  458
# Número de requests:  460
# New-kline gravada no banco no ciclo:  459
# Número de requests:  461
# New-kline gravada no banco no ciclo:  460
# Número de requests:  462
# New-kline gravada no banco no ciclo:  461
# Número de requests:  463
# New-kline gravada no banco no ciclo:  462
# Número de requests:  464
# New-kline gravada no banco no ciclo:  463
# Número de requests:  465
# New-kline gravada no banco no ciclo:  464
# Número de requests:  466
# New-kline gravada no banco no ciclo:  465
# Número de requests:  467
# New-kline gravada no banco no ciclo:  466
# Número de requests:  468
# New-kline gravada no banco no ciclo:  467
# Número de requests:  469
# New-kline gravada no banco no ciclo:  468
# Número de requests:  470
# New-kline gravada no banco no ciclo:  469
# Número de requests:  471
# New-kline gravada no banco no ciclo:  470
# Número de requests:  472
# New-kline gravada no banco no ciclo:  471
# Número de requests:  473
# New-kline gravada no banco no ciclo:  472
# Número de requests:  474
# New-kline gravada no banco no ciclo:  473
# Número de requests:  475
# New-kline gravada no banco no ciclo:  474
# Número de requests:  476
# New-kline gravada no banco no ciclo:  475
# Número de requests:  477
# New-kline gravada no banco no ciclo:  476
# Número de requests:  478
# New-kline gravada no banco no ciclo:  477
# Número de requests:  479
# New-kline gravada no banco no ciclo:  478
# Número de requests:  480
# New-kline gravada no banco no ciclo:  479
# Número de requests:  481
# New-kline gravada no banco no ciclo:  480
# Número de requests:  482
# New-kline gravada no banco no ciclo:  481
# Número de requests:  483
# New-kline gravada no banco no ciclo:  482
# Número de requests:  484
# New-kline gravada no banco no ciclo:  483
# Número de requests:  485
# New-kline gravada no banco no ciclo:  484
# Número de requests:  486
# New-kline gravada no banco no ciclo:  485
# Número de requests:  487
# New-kline gravada no banco no ciclo:  486
# Número de requests:  488
# New-kline gravada no banco no ciclo:  487
# Número de requests:  489
# New-kline gravada no banco no ciclo:  488
# Número de requests:  490
# New-kline gravada no banco no ciclo:  489
# Número de requests:  491
# New-kline gravada no banco no ciclo:  490
# Número de requests:  492
# New-kline gravada no banco no ciclo:  491
# Número de requests:  493
# New-kline gravada no banco no ciclo:  492
# Número de requests:  494
# New-kline gravada no banco no ciclo:  493
# Número de requests:  495
# New-kline gravada no banco no ciclo:  494
# Número de requests:  496
# New-kline gravada no banco no ciclo:  495
# Número de requests:  497
# New-kline gravada no banco no ciclo:  496
# Número de requests:  498
# New-kline gravada no banco no ciclo:  497
# Número de requests:  499
# New-kline gravada no banco no ciclo:  498
# Número de requests:  500
# New-kline gravada no banco no ciclo:  499
# Número de requests:  501
# New-kline gravada no banco no ciclo:  500
# Número de requests:  502
# New-kline gravada no banco no ciclo:  501
# Número de requests:  503
# New-kline gravada no banco no ciclo:  502
# Número de requests:  504
# New-kline gravada no banco no ciclo:  503
# Número de requests:  505
# New-kline gravada no banco no ciclo:  504
# Número de requests:  506
# New-kline gravada no banco no ciclo:  505
# Número de requests:  507
# New-kline gravada no banco no ciclo:  506
# Número de requests:  508
# New-kline gravada no banco no ciclo:  507
# Número de requests:  509
# New-kline gravada no banco no ciclo:  508
# Número de requests:  510
# New-kline gravada no banco no ciclo:  509
# Número de requests:  511
# New-kline gravada no banco no ciclo:  510
# Número de requests:  512
# New-kline gravada no banco no ciclo:  511
# Número de requests:  513
# New-kline gravada no banco no ciclo:  512
# Número de requests:  514
# New-kline gravada no banco no ciclo:  513
# Número de requests:  515
# New-kline gravada no banco no ciclo:  514
# Número de requests:  516
# New-kline gravada no banco no ciclo:  515
# Número de requests:  517
# New-kline gravada no banco no ciclo:  516
# Número de requests:  518
# New-kline gravada no banco no ciclo:  517
# Número de requests:  519
# New-kline gravada no banco no ciclo:  518
# Número de requests:  520
# New-kline gravada no banco no ciclo:  519
# Número de requests:  521
# New-kline gravada no banco no ciclo:  520
# Número de requests:  522
# New-kline gravada no banco no ciclo:  521
# Número de requests:  523
# New-kline gravada no banco no ciclo:  522
# Número de requests:  524
# New-kline gravada no banco no ciclo:  523
# Número de requests:  525
# New-kline gravada no banco no ciclo:  524
# Número de requests:  526
# New-kline gravada no banco no ciclo:  525
# Número de requests:  527
# New-kline gravada no banco no ciclo:  526
# Número de requests:  528
# New-kline gravada no banco no ciclo:  527
# Número de requests:  529
# New-kline gravada no banco no ciclo:  528
# Número de requests:  530
# New-kline gravada no banco no ciclo:  529
# Número de requests:  531
# New-kline gravada no banco no ciclo:  530
# Número de requests:  532
# New-kline gravada no banco no ciclo:  531
# Número de requests:  533
# New-kline gravada no banco no ciclo:  532
# Número de requests:  534
# New-kline gravada no banco no ciclo:  533
# Número de requests:  535
# New-kline gravada no banco no ciclo:  534
# Número de requests:  536
# New-kline gravada no banco no ciclo:  535
# Número de requests:  537
# New-kline gravada no banco no ciclo:  536
# Número de requests:  538
# New-kline gravada no banco no ciclo:  537
# Número de requests:  539
# New-kline gravada no banco no ciclo:  538
# Número de requests:  540
# New-kline gravada no banco no ciclo:  539
# Número de requests:  541
# New-kline gravada no banco no ciclo:  540
# Número de requests:  542
# New-kline gravada no banco no ciclo:  541
# Número de requests:  543
# New-kline gravada no banco no ciclo:  542
# Número de requests:  544
# New-kline gravada no banco no ciclo:  543
# Número de requests:  545
# New-kline gravada no banco no ciclo:  544
# Número de requests:  546
# New-kline gravada no banco no ciclo:  545
# Número de requests:  547
# New-kline gravada no banco no ciclo:  546
# Número de requests:  548
# New-kline gravada no banco no ciclo:  547
# Número de requests:  549
# New-kline gravada no banco no ciclo:  548
# Número de requests:  550
# New-kline gravada no banco no ciclo:  549
# Número de requests:  551
# New-kline gravada no banco no ciclo:  550
# Número de requests:  552
# New-kline gravada no banco no ciclo:  551
# Número de requests:  553
# New-kline gravada no banco no ciclo:  552
# Número de requests:  554
# New-kline gravada no banco no ciclo:  553
# Número de requests:  555
# New-kline gravada no banco no ciclo:  554
# Número de requests:  556
# New-kline gravada no banco no ciclo:  555
# Número de requests:  557
# New-kline gravada no banco no ciclo:  556
# Número de requests:  558
# New-kline gravada no banco no ciclo:  557
# Número de requests:  559
# New-kline gravada no banco no ciclo:  558
# Número de requests:  560
# New-kline gravada no banco no ciclo:  559
# Número de requests:  561
# New-kline gravada no banco no ciclo:  560
# Número de requests:  562
# New-kline gravada no banco no ciclo:  561
# Número de requests:  563
# New-kline gravada no banco no ciclo:  562
# Número de requests:  564
# New-kline gravada no banco no ciclo:  563
# Número de requests:  565
# New-kline gravada no banco no ciclo:  564
# Número de requests:  566
# New-kline gravada no banco no ciclo:  565
# Número de requests:  567
# New-kline gravada no banco no ciclo:  566
# Número de requests:  568
# New-kline gravada no banco no ciclo:  567
# Número de requests:  569
# New-kline gravada no banco no ciclo:  568
# Número de requests:  570
# New-kline gravada no banco no ciclo:  569
# Número de requests:  571
# New-kline gravada no banco no ciclo:  570
# Número de requests:  572
# New-kline gravada no banco no ciclo:  571
# Número de requests:  573
# New-kline gravada no banco no ciclo:  572
# Número de requests:  574
# New-kline gravada no banco no ciclo:  573
# Número de requests:  575
# New-kline gravada no banco no ciclo:  574
# Número de requests:  576
# New-kline gravada no banco no ciclo:  575
# Número de requests:  577
# New-kline gravada no banco no ciclo:  576
# Número de requests:  578
# New-kline gravada no banco no ciclo:  577
# Número de requests:  579
# New-kline gravada no banco no ciclo:  578
# Número de requests:  580
# New-kline gravada no banco no ciclo:  579
# Número de requests:  581
# New-kline gravada no banco no ciclo:  580
# Número de requests:  582
# New-kline gravada no banco no ciclo:  581
# Número de requests:  583
# New-kline gravada no banco no ciclo:  582
# Número de requests:  584
# New-kline gravada no banco no ciclo:  583
# Número de requests:  585
# New-kline gravada no banco no ciclo:  584
# Número de requests:  586
# New-kline gravada no banco no ciclo:  585
# Número de requests:  587
# New-kline gravada no banco no ciclo:  586
# Número de requests:  588
# New-kline gravada no banco no ciclo:  587
# Número de requests:  589
# New-kline gravada no banco no ciclo:  588
# Número de requests:  590
# New-kline gravada no banco no ciclo:  589
# Número de requests:  591
# New-kline gravada no banco no ciclo:  590
# Número de requests:  592
# New-kline gravada no banco no ciclo:  591
# Número de requests:  593
# New-kline gravada no banco no ciclo:  592
# Número de requests:  594
# New-kline gravada no banco no ciclo:  593
# Número de requests:  595
# New-kline gravada no banco no ciclo:  594
# Número de requests:  596
# New-kline gravada no banco no ciclo:  595
# Número de requests:  597
# New-kline gravada no banco no ciclo:  596
# Número de requests:  598
# New-kline gravada no banco no ciclo:  597
# Número de requests:  599
# New-kline gravada no banco no ciclo:  598
# Número de requests:  600
# New-kline gravada no banco no ciclo:  599
# Número de requests:  601
# New-kline gravada no banco no ciclo:  600
# Número de requests:  602
# New-kline gravada no banco no ciclo:  601
# Número de requests:  603
# New-kline gravada no banco no ciclo:  602
# Número de requests:  604
# New-kline gravada no banco no ciclo:  603
# Número de requests:  605
# New-kline gravada no banco no ciclo:  604
# Número de requests:  606
# New-kline gravada no banco no ciclo:  605
# Número de requests:  607
# New-kline gravada no banco no ciclo:  606
# Número de requests:  608
# New-kline gravada no banco no ciclo:  607
# Número de requests:  609
# New-kline gravada no banco no ciclo:  608
# Número de requests:  610
# New-kline gravada no banco no ciclo:  609
# Número de requests:  611
# New-kline gravada no banco no ciclo:  610
# Número de requests:  612
# New-kline gravada no banco no ciclo:  611
# Número de requests:  613
# New-kline gravada no banco no ciclo:  612
# Número de requests:  614
# New-kline gravada no banco no ciclo:  613
# Número de requests:  615
# New-kline gravada no banco no ciclo:  614
# Número de requests:  616
# New-kline gravada no banco no ciclo:  615
# Número de requests:  617
# New-kline gravada no banco no ciclo:  616
# Número de requests:  618
# New-kline gravada no banco no ciclo:  617
# Número de requests:  619
# New-kline gravada no banco no ciclo:  618
# Número de requests:  620
# New-kline gravada no banco no ciclo:  619
# Número de requests:  621
# New-kline gravada no banco no ciclo:  620
# Número de requests:  622
# New-kline gravada no banco no ciclo:  621
# Número de requests:  623
# New-kline gravada no banco no ciclo:  622
# Número de requests:  624
# New-kline gravada no banco no ciclo:  623
# Número de requests:  625
# New-kline gravada no banco no ciclo:  624
# Número de requests:  626
# New-kline gravada no banco no ciclo:  625
# Número de requests:  627
# New-kline gravada no banco no ciclo:  626
# Número de requests:  628
# New-kline gravada no banco no ciclo:  627
# Número de requests:  629
# New-kline gravada no banco no ciclo:  628
# Número de requests:  630
# New-kline gravada no banco no ciclo:  629
# Número de requests:  631
# New-kline gravada no banco no ciclo:  630
# Número de requests:  632
# New-kline gravada no banco no ciclo:  631
# Número de requests:  633
# New-kline gravada no banco no ciclo:  632
# Número de requests:  634
# New-kline gravada no banco no ciclo:  633
# Número de requests:  635
# New-kline gravada no banco no ciclo:  634
# Número de requests:  636
# New-kline gravada no banco no ciclo:  635
# Número de requests:  637
# New-kline gravada no banco no ciclo:  636
# Número de requests:  638
# New-kline gravada no banco no ciclo:  637
# Número de requests:  639
# New-kline gravada no banco no ciclo:  638
# Número de requests:  640
# New-kline gravada no banco no ciclo:  639
# Número de requests:  641
# New-kline gravada no banco no ciclo:  640
# Número de requests:  642
# New-kline gravada no banco no ciclo:  641
# Número de requests:  643
# New-kline gravada no banco no ciclo:  642
# Número de requests:  644
# New-kline gravada no banco no ciclo:  643
# Número de requests:  645
# New-kline gravada no banco no ciclo:  644
# Número de requests:  646
# New-kline gravada no banco no ciclo:  645
# Número de requests:  647
# New-kline gravada no banco no ciclo:  646
# Número de requests:  648
# New-kline gravada no banco no ciclo:  647
# Número de requests:  649
# New-kline gravada no banco no ciclo:  648
# Número de requests:  650
# New-kline gravada no banco no ciclo:  649
# Número de requests:  651
# New-kline gravada no banco no ciclo:  650
# Número de requests:  652
# New-kline gravada no banco no ciclo:  651
# Número de requests:  653
# New-kline gravada no banco no ciclo:  652
# Número de requests:  654
# New-kline gravada no banco no ciclo:  653
# Número de requests:  655
# New-kline gravada no banco no ciclo:  654
# Número de requests:  656
# New-kline gravada no banco no ciclo:  655
# Número de requests:  657
# New-kline gravada no banco no ciclo:  656
# Número de requests:  658
# New-kline gravada no banco no ciclo:  657
# Número de requests:  659
# New-kline gravada no banco no ciclo:  658
# Número de requests:  660
# New-kline gravada no banco no ciclo:  659
# Número de requests:  661
# New-kline gravada no banco no ciclo:  660
# Número de requests:  662
# New-kline gravada no banco no ciclo:  661
# Número de requests:  663
# New-kline gravada no banco no ciclo:  662
# Número de requests:  664
# New-kline gravada no banco no ciclo:  663
# Número de requests:  665
# New-kline gravada no banco no ciclo:  664
# Número de requests:  666
# New-kline gravada no banco no ciclo:  665
# Número de requests:  667
# New-kline gravada no banco no ciclo:  666
# Número de requests:  668
# New-kline gravada no banco no ciclo:  667
# Número de requests:  669
# New-kline gravada no banco no ciclo:  668
# Número de requests:  670
# New-kline gravada no banco no ciclo:  669
# Número de requests:  671
# New-kline gravada no banco no ciclo:  670
# Número de requests:  672
# New-kline gravada no banco no ciclo:  671
# Número de requests:  673
# New-kline gravada no banco no ciclo:  672
# Número de requests:  674
# New-kline gravada no banco no ciclo:  673
# Número de requests:  675
# New-kline gravada no banco no ciclo:  674
# Número de requests:  676
# New-kline gravada no banco no ciclo:  675
# Número de requests:  677
# New-kline gravada no banco no ciclo:  676
# Número de requests:  678
# New-kline gravada no banco no ciclo:  677
# Número de requests:  679
# New-kline gravada no banco no ciclo:  678
# Número de requests:  680
# New-kline gravada no banco no ciclo:  679
# Número de requests:  681
# New-kline gravada no banco no ciclo:  680
# Número de requests:  682
# New-kline gravada no banco no ciclo:  681
# Número de requests:  683
# New-kline gravada no banco no ciclo:  682
# Número de requests:  684
# New-kline gravada no banco no ciclo:  683
# Número de requests:  685
# New-kline gravada no banco no ciclo:  684
# Número de requests:  686
# New-kline gravada no banco no ciclo:  685
# Número de requests:  687
# New-kline gravada no banco no ciclo:  686
# Número de requests:  688
# New-kline gravada no banco no ciclo:  687
# Número de requests:  689
# New-kline gravada no banco no ciclo:  688
# Número de requests:  690
# New-kline gravada no banco no ciclo:  689
# Número de requests:  691
# New-kline gravada no banco no ciclo:  690
# Número de requests:  692
# New-kline gravada no banco no ciclo:  691
# Número de requests:  693
# New-kline gravada no banco no ciclo:  692
# Número de requests:  694
# New-kline gravada no banco no ciclo:  693
# Número de requests:  695
# New-kline gravada no banco no ciclo:  694
# Número de requests:  696
# New-kline gravada no banco no ciclo:  695
# Número de requests:  697
# New-kline gravada no banco no ciclo:  696
# Número de requests:  698
# New-kline gravada no banco no ciclo:  697
# Número de requests:  699
# New-kline gravada no banco no ciclo:  698
# Número de requests:  700
# New-kline gravada no banco no ciclo:  699
# Número de requests:  701
# New-kline gravada no banco no ciclo:  700
# Número de requests:  702
# New-kline gravada no banco no ciclo:  701
# Número de requests:  703
# New-kline gravada no banco no ciclo:  702
# Número de requests:  704
# New-kline gravada no banco no ciclo:  703
# Número de requests:  705
# New-kline gravada no banco no ciclo:  704
# Número de requests:  706
# New-kline gravada no banco no ciclo:  705
# Número de requests:  707
# New-kline gravada no banco no ciclo:  706
# Número de requests:  708
# New-kline gravada no banco no ciclo:  707
# Número de requests:  709
# New-kline gravada no banco no ciclo:  708
# Número de requests:  710
# New-kline gravada no banco no ciclo:  709
# Número de requests:  711
# New-kline gravada no banco no ciclo:  710
# Número de requests:  712
# New-kline gravada no banco no ciclo:  711
# Número de requests:  713
# New-kline gravada no banco no ciclo:  712
# Número de requests:  714
# New-kline gravada no banco no ciclo:  713
# ...
# Número de requests:  653
# New-kline gravada no banco no ciclo:  1653
# Número de requests:  654
# New-kline gravada no banco no ciclo:  1654
# Número de requests:  655
# New-kline gravada no banco no ciclo:  1655
# Número de requests:  656
# New-kline gravada no banco no ciclo:  1656
# Número de requests:  657
# New-kline gravada no banco no ciclo:  1657
# Número de requests:  658
# New-kline gravada no banco no ciclo:  1658
# Número de requests:  659
# New-kline gravada no banco no ciclo:  1659
# Número de requests:  660
# New-kline gravada no banco no ciclo:  1660
# Número de requests:  661
# New-kline gravada no banco no ciclo:  1661
# Número de requests:  662
# New-kline gravada no banco no ciclo:  1662
# Número de requests:  663
# New-kline gravada no banco no ciclo:  1663
# Número de requests:  664
# New-kline gravada no banco no ciclo:  1664
# Número de requests:  665
# New-kline gravada no banco no ciclo:  1665
# Número de requests:  666
# New-kline gravada no banco no ciclo:  1666
# Número de requests:  667
# New-kline gravada no banco no ciclo:  1667
# Número de requests:  668
# New-kline gravada no banco no ciclo:  1668
# Número de requests:  669
# New-kline gravada no banco no ciclo:  1669
# Número de requests:  670
# New-kline gravada no banco no ciclo:  1670
# Número de requests:  671
# New-kline gravada no banco no ciclo:  1671
# Número de requests:  672
# New-kline gravada no banco no ciclo:  1672
# Número de requests:  673
# New-kline gravada no banco no ciclo:  1673
# Número de requests:  674
# New-kline gravada no banco no ciclo:  1674
# Número de requests:  675
# New-kline gravada no banco no ciclo:  1675
# Número de requests:  676
# New-kline gravada no banco no ciclo:  1676
# Número de requests:  677
# New-kline gravada no banco no ciclo:  1677
# Número de requests:  678
# New-kline gravada no banco no ciclo:  1678
# Número de requests:  679
# New-kline gravada no banco no ciclo:  1679
# Número de requests:  680
# New-kline gravada no banco no ciclo:  1680
# Número de requests:  681
# New-kline gravada no banco no ciclo:  1681
# Número de requests:  682
# New-kline gravada no banco no ciclo:  1682
# Número de requests:  683
# New-kline gravada no banco no ciclo:  1683
# Número de requests:  684
# New-kline gravada no banco no ciclo:  1684
# Número de requests:  685
# New-kline gravada no banco no ciclo:  1685
# Número de requests:  686
# New-kline gravada no banco no ciclo:  1686
# Número de requests:  687
# New-kline gravada no banco no ciclo:  1687
# Número de requests:  688
# New-kline gravada no banco no ciclo:  1688
# Número de requests:  689
# New-kline gravada no banco no ciclo:  1689
# Número de requests:  690
# New-kline gravada no banco no ciclo:  1690
# Número de requests:  691
# New-kline gravada no banco no ciclo:  1691
# Número de requests:  692
# New-kline gravada no banco no ciclo:  1692
# Número de requests:  693
# New-kline gravada no banco no ciclo:  1693
# Número de requests:  694
# New-kline gravada no banco no ciclo:  1694
# Número de requests:  695
# New-kline gravada no banco no ciclo:  1695
# Número de requests:  696
# New-kline gravada no banco no ciclo:  1696
# Número de requests:  697
# New-kline gravada no banco no ciclo:  1697
# Número de requests:  698
# New-kline gravada no banco no ciclo:  1698
# Número de requests:  699
# New-kline gravada no banco no ciclo:  1699
# Número de requests:  700
# New-kline gravada no banco no ciclo:  1700
# Número de requests:  701
# New-kline gravada no banco no ciclo:  1701
# Número de requests:  702
# New-kline gravada no banco no ciclo:  1702
# Número de requests:  703
# New-kline gravada no banco no ciclo:  1703
# Número de requests:  704
# New-kline gravada no banco no ciclo:  1704
# Número de requests:  705
# New-kline gravada no banco no ciclo:  1705
# Número de requests:  706
# New-kline gravada no banco no ciclo:  1706
# Número de requests:  707
# New-kline gravada no banco no ciclo:  1707
# Número de requests:  708
# New-kline gravada no banco no ciclo:  1708
# Número de requests:  709
# New-kline gravada no banco no ciclo:  1709
# Número de requests:  710
# New-kline gravada no banco no ciclo:  1710
# Número de requests:  711
# New-kline gravada no banco no ciclo:  1711
# Número de requests:  712
# New-kline gravada no banco no ciclo:  1712
# Número de requests:  713
# New-kline gravada no banco no ciclo:  1713
# Número de requests:  714
# New-kline gravada no banco no ciclo:  1714
# Número de requests:  715
# New-kline gravada no banco no ciclo:  1715
# Número de requests:  716
# New-kline gravada no banco no ciclo:  1716
# Número de requests:  717
# New-kline gravada no banco no ciclo:  1717
# Número de requests:  718
# New-kline gravada no banco no ciclo:  1718
# Número de requests:  719
# New-kline gravada no banco no ciclo:  1719
# Número de requests:  720
# New-kline gravada no banco no ciclo:  1720
# Número de requests:  721
# New-kline gravada no banco no ciclo:  1721
# Número de requests:  722
# New-kline gravada no banco no ciclo:  1722
# Número de requests:  723
# New-kline gravada no banco no ciclo:  1723
# Número de requests:  724
# New-kline gravada no banco no ciclo:  1724
# Número de requests:  725
# New-kline gravada no banco no ciclo:  1725
# Número de requests:  726
# New-kline gravada no banco no ciclo:  1726
# Número de requests:  727
# New-kline gravada no banco no ciclo:  1727
# Número de requests:  728
# New-kline gravada no banco no ciclo:  1728
# Número de requests:  729
# New-kline gravada no banco no ciclo:  1729
# Número de requests:  730
# New-kline gravada no banco no ciclo:  1730
# Número de requests:  731
# New-kline gravada no banco no ciclo:  1731
# Número de requests:  732
# New-kline gravada no banco no ciclo:  1732
# Número de requests:  733
# New-kline gravada no banco no ciclo:  1733
# Número de requests:  734
# New-kline gravada no banco no ciclo:  1734
# Número de requests:  735
# New-kline gravada no banco no ciclo:  1735
# Número de requests:  736
# New-kline gravada no banco no ciclo:  1736
# Número de requests:  737
# New-kline gravada no banco no ciclo:  1737
# Número de requests:  738
# New-kline gravada no banco no ciclo:  1738
# Número de requests:  739
# New-kline gravada no banco no ciclo:  1739
# Número de requests:  740
# New-kline gravada no banco no ciclo:  1740
# Número de requests:  741
# New-kline gravada no banco no ciclo:  1741
# Número de requests:  742
# New-kline gravada no banco no ciclo:  1742
# Número de requests:  743
# New-kline gravada no banco no ciclo:  1743
# Número de requests:  744
# New-kline gravada no banco no ciclo:  1744
# Número de requests:  745
# New-kline gravada no banco no ciclo:  1745
# Número de requests:  746
# New-kline gravada no banco no ciclo:  1746
# Número de requests:  747
# New-kline gravada no banco no ciclo:  1747
# Número de requests:  748
# New-kline gravada no banco no ciclo:  1748
# Número de requests:  749
# New-kline gravada no banco no ciclo:  1749
# Número de requests:  750
# New-kline gravada no banco no ciclo:  1750
# Número de requests:  751
# New-kline gravada no banco no ciclo:  1751
# Número de requests:  752
# New-kline gravada no banco no ciclo:  1752
# Número de requests:  753
# New-kline gravada no banco no ciclo:  1753
# Número de requests:  754
# New-kline gravada no banco no ciclo:  1754
# Número de requests:  755
# New-kline gravada no banco no ciclo:  1755
# Número de requests:  756
# New-kline gravada no banco no ciclo:  1756
# Número de requests:  757
# New-kline gravada no banco no ciclo:  1757
# Número de requests:  758
# New-kline gravada no banco no ciclo:  1758
# Número de requests:  759
# New-kline gravada no banco no ciclo:  1759
# Número de requests:  760
# New-kline gravada no banco no ciclo:  1760
# Número de requests:  761
# New-kline gravada no banco no ciclo:  1761
# Número de requests:  762
# New-kline gravada no banco no ciclo:  1762
# Número de requests:  763
# New-kline gravada no banco no ciclo:  1763
# Número de requests:  764
# New-kline gravada no banco no ciclo:  1764
# Número de requests:  765
# New-kline gravada no banco no ciclo:  1765
# Número de requests:  766
# New-kline gravada no banco no ciclo:  1766
# Número de requests:  767
# New-kline gravada no banco no ciclo:  1767
# Número de requests:  768
# New-kline gravada no banco no ciclo:  1768
# Número de requests:  769
# New-kline gravada no banco no ciclo:  1769
# Número de requests:  770
# New-kline gravada no banco no ciclo:  1770
# Número de requests:  771
# New-kline gravada no banco no ciclo:  1771
# Número de requests:  772
# New-kline gravada no banco no ciclo:  1772
# Número de requests:  773
# New-kline gravada no banco no ciclo:  1773
# Número de requests:  774
# New-kline gravada no banco no ciclo:  1774
# Número de requests:  775
# New-kline gravada no banco no ciclo:  1775
# Número de requests:  776
# New-kline gravada no banco no ciclo:  1776
# Número de requests:  777
# New-kline gravada no banco no ciclo:  1777
# Número de requests:  778
# New-kline gravada no banco no ciclo:  1778
# Número de requests:  779
# New-kline gravada no banco no ciclo:  1779
# Número de requests:  780
# New-kline gravada no banco no ciclo:  1780
# Número de requests:  781
# New-kline gravada no banco no ciclo:  1781
# Número de requests:  782
# New-kline gravada no banco no ciclo:  1782
# Número de requests:  783
# New-kline gravada no banco no ciclo:  1783
# Número de requests:  784
# New-kline gravada no banco no ciclo:  1784
# Número de requests:  785
# New-kline gravada no banco no ciclo:  1785
# Número de requests:  786
# New-kline gravada no banco no ciclo:  1786
# Número de requests:  787
# New-kline gravada no banco no ciclo:  1787
# Número de requests:  788
# New-kline gravada no banco no ciclo:  1788
# Número de requests:  789
# New-kline gravada no banco no ciclo:  1789
# Número de requests:  790
# New-kline gravada no banco no ciclo:  1790
# Número de requests:  791
# New-kline gravada no banco no ciclo:  1791
# Número de requests:  792
# New-kline gravada no banco no ciclo:  1792
# Número de requests:  793
# New-kline gravada no banco no ciclo:  1793
# Número de requests:  794
# New-kline gravada no banco no ciclo:  1794
# Número de requests:  795
# New-kline gravada no banco no ciclo:  1795
# Número de requests:  796
# New-kline gravada no banco no ciclo:  1796
# Número de requests:  797
# New-kline gravada no banco no ciclo:  1797
# Número de requests:  798
# New-kline gravada no banco no ciclo:  1798
# Número de requests:  799
# New-kline gravada no banco no ciclo:  1799
# Número de requests:  800
# New-kline gravada no banco no ciclo:  1800
# Número de requests:  801
# New-kline gravada no banco no ciclo:  1801
# Número de requests:  802
# New-kline gravada no banco no ciclo:  1802
# Número de requests:  803
# New-kline gravada no banco no ciclo:  1803
# Número de requests:  804
# New-kline gravada no banco no ciclo:  1804
# Número de requests:  805
# New-kline gravada no banco no ciclo:  1805
# Número de requests:  806
# New-kline gravada no banco no ciclo:  1806
# Número de requests:  807
# New-kline gravada no banco no ciclo:  1807
# Número de requests:  808
# New-kline gravada no banco no ciclo:  1808
# Número de requests:  809
# New-kline gravada no banco no ciclo:  1809
# Número de requests:  810
# New-kline gravada no banco no ciclo:  1810
# Número de requests:  811
# New-kline gravada no banco no ciclo:  1811
# Número de requests:  812
# New-kline gravada no banco no ciclo:  1812
# Número de requests:  813
# New-kline gravada no banco no ciclo:  1813
# Número de requests:  814
# New-kline gravada no banco no ciclo:  1814
# Número de requests:  815
# New-kline gravada no banco no ciclo:  1815
# Número de requests:  816
# New-kline gravada no banco no ciclo:  1816
# Número de requests:  817
# New-kline gravada no banco no ciclo:  1817
# Número de requests:  818
# New-kline gravada no banco no ciclo:  1818
# Número de requests:  819
# New-kline gravada no banco no ciclo:  1819
# Número de requests:  820
# New-kline gravada no banco no ciclo:  1820
# Número de requests:  821
# New-kline gravada no banco no ciclo:  1821
# Número de requests:  822
# New-kline gravada no banco no ciclo:  1822
# Número de requests:  823
# New-kline gravada no banco no ciclo:  1823
# Número de requests:  824
# New-kline gravada no banco no ciclo:  1824
# Número de requests:  825
# New-kline gravada no banco no ciclo:  1825
# Número de requests:  826
# New-kline gravada no banco no ciclo:  1826
# Número de requests:  827
# New-kline gravada no banco no ciclo:  1827
# Número de requests:  828
# New-kline gravada no banco no ciclo:  1828
# Número de requests:  829
# New-kline gravada no banco no ciclo:  1829
# Número de requests:  830
# New-kline gravada no banco no ciclo:  1830
# Número de requests:  831
# New-kline gravada no banco no ciclo:  1831
# Número de requests:  832
# New-kline gravada no banco no ciclo:  1832
# Número de requests:  833
# New-kline gravada no banco no ciclo:  1833
# Número de requests:  834
# New-kline gravada no banco no ciclo:  1834
# Número de requests:  835
# New-kline gravada no banco no ciclo:  1835
# Número de requests:  836
# New-kline gravada no banco no ciclo:  1836
# Número de requests:  837
# New-kline gravada no banco no ciclo:  1837
# Número de requests:  838
# New-kline gravada no banco no ciclo:  1838
# Número de requests:  839
# New-kline gravada no banco no ciclo:  1839
# Número de requests:  840
# New-kline gravada no banco no ciclo:  1840
# Número de requests:  841
# New-kline gravada no banco no ciclo:  1841
# Número de requests:  842
# New-kline gravada no banco no ciclo:  1842
# Número de requests:  843
# New-kline gravada no banco no ciclo:  1843
# Número de requests:  844
# New-kline gravada no banco no ciclo:  1844
# Número de requests:  845
# New-kline gravada no banco no ciclo:  1845
# Número de requests:  846
# New-kline gravada no banco no ciclo:  1846
# Número de requests:  847
# New-kline gravada no banco no ciclo:  1847
# Número de requests:  848
# New-kline gravada no banco no ciclo:  1848
# Número de requests:  849
# New-kline gravada no banco no ciclo:  1849
# Número de requests:  850
# New-kline gravada no banco no ciclo:  1850
# Número de requests:  851
# New-kline gravada no banco no ciclo:  1851
# Número de requests:  852
# New-kline gravada no banco no ciclo:  1852
# Número de requests:  853
# New-kline gravada no banco no ciclo:  1853
# Número de requests:  854
# New-kline gravada no banco no ciclo:  1854
# Número de requests:  855
# New-kline gravada no banco no ciclo:  1855
# Número de requests:  856
# New-kline gravada no banco no ciclo:  1856
# Número de requests:  857
# New-kline gravada no banco no ciclo:  1857
# Número de requests:  858
# New-kline gravada no banco no ciclo:  1858
# Número de requests:  859
# New-kline gravada no banco no ciclo:  1859
# Número de requests:  860
# New-kline gravada no banco no ciclo:  1860
# Número de requests:  861
# New-kline gravada no banco no ciclo:  1861
# Número de requests:  862
# New-kline gravada no banco no ciclo:  1862
# Número de requests:  863
# New-kline gravada no banco no ciclo:  1863
# Número de requests:  864
# New-kline gravada no banco no ciclo:  1864
# Número de requests:  865
# New-kline gravada no banco no ciclo:  1865
# Número de requests:  866
# New-kline gravada no banco no ciclo:  1866
# Número de requests:  867
# New-kline gravada no banco no ciclo:  1867
# Número de requests:  868
# New-kline gravada no banco no ciclo:  1868
# Número de requests:  869
# New-kline gravada no banco no ciclo:  1869
# Número de requests:  870
# New-kline gravada no banco no ciclo:  1870
# Número de requests:  871
# New-kline gravada no banco no ciclo:  1871
# Número de requests:  872
# New-kline gravada no banco no ciclo:  1872
# Número de requests:  873
# New-kline gravada no banco no ciclo:  1873
# Número de requests:  874
# New-kline gravada no banco no ciclo:  1874
# Número de requests:  875
# dado mais atual, este foi o último ciclo
# New-kline gravada no banco no ciclo:  1875
# Atualizando par  BTCUSDT  para full. Status =  done
#
# Par:  BTCUSDT  Historico ausente, completar
# dormindo 1 min
# Ciclo mais externo =  2
# Tabela de pares encontrada
# massa de dados completa
# dormindo 1 min
# Ciclo mais externo =  3
# Tabela de pares encontrada
# massa de dados completa
# dormindo 1 min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-bf2d6db877b4> in <module>
#      78         ciclo_externo+=1
#      79         print('dormindo 1 min')
# ---> 80         time.sleep(60) #Ajeitar para acordar poucos segundos após fechamento do próximo candle
#      81
#      82     #Descansa 5min se não houver a tabela de pares
#
# KeyboardInterrupt:

# %%
def db_get_pairs_table():
    
    pairs = []
    
    try:

        connection = psycopg2.connect(host=DB_HOST, database=POSTGRES_DB, 
                                      user=POSTGRES_USER, password=POSTGRES_PASSWORD)

        pointer = connection.cursor(cursor_factory=psycopg2.extras.DictCursor)

        sql_select_query = 'SELECT * FROM getdata_pair'

        pointer.execute(sql_select_query)
        
        pairs = pointer.fetchall()
        
        #return pairs
        
    except (Exception, psycopg2.Error) as error:

        #print("Error in SELECT operation", error)

        pointer.execute("ROLLBACK")

    finally:

        if (connection):
            pointer.close()
            connection.close()
    
    return pairs
    
def db_update_pair_table(pair, historical):
    
    try:

        connection = psycopg2.connect(host=DB_HOST, database=POSTGRES_DB, 
                                      user=POSTGRES_USER, password=POSTGRES_PASSWORD)

        pointer = connection.cursor(cursor_factory=psycopg2.extras.DictCursor)

        sql_update_query = """Update getdata_pair set historical = %s where pair_name = %s"""

        pointer.execute(sql_update_query, (historical, pair))

        connection.commit()

        return 'done'

    except (Exception, psycopg2.Error) as error:

        print("Error in update operation", error)

        pointer.execute("ROLLBACK")

        return 'fail'

    finally:

        if (connection):
            pointer.close()
            connection.close()
            
def db_save_kline(pair,klines):
    
    candles_table_name = 'klines_1m_' + pair
    
    SQL = '''
    INSERT INTO ''' + candles_table_name + '''
    (open_time, open, high, low, close, volume, 
    quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, 
    taker_buy_quote_asset_volume) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    '''

    try:
        
        connection = psycopg2.connect(host=DB_HOST, database=POSTGRES_DB, 
                                      user=POSTGRES_USER, password=POSTGRES_PASSWORD)
        
        pointer = connection.cursor(cursor_factory=psycopg2.extras.DictCursor)
        
        for kline in klines:
        
            data = (datetime.fromtimestamp(kline[0]/1000), kline[1], kline[2], 
                    kline[3], kline[4], kline[5], kline[7], kline[8], kline[9], kline[10],)
        
            try:
                
                pointer.execute(SQL, data)
            
            except:
                
                pointer.execute("ROLLBACK")
                pass
        
        return 'done'
        
    except (Exception, psycopg2.Error) as error:
        
        print("Error in Save operation", error)
        
        pointer.execute("ROLLBACK")
        
        return 'fail'
        
    finally:

        if (connection):
            
            connection.commit()
            pointer.close()
            connection.close()

# %%
def get_historical_data(pair, max_requests):
    
    db_update_status = db_update_pair_table(pair,'building')
    print ('Atualizando par ', pair, ' para buiding. Status = ',db_update_status)
    print(' ')

    num_requests = 0
    
    for i in range(10):
        
        url = 'https://api.binance.com/api/v1/klines?symbol='+pair+'&interval=1m&startTime=1241893500000'
        
        try:

            response = requests.get(url)
            
            oldest_klines = response.json()
            
            binance_commmunication = 'ok'
            
            num_requests+= 1
            
            print ('entrada ok, na tentativa: ',i)
            print(' ')
            
            break
            
        except Exception as error:
            
            print('Comunicação com a binance falhou na entrada, erro: ',error) #Na verdade enviar para destino apropriado

            time.sleep(5)
        
    if (binance_commmunication == 'ok'):
        
        db_save_kline_status = db_save_kline(pair,oldest_klines)
        
        if (db_save_kline_status == 'done'):
            
            print('Oldest request gravada no banco')
            print(' ')
            
            step = 60000
            delta_time = 500*step
            start_time = int((oldest_klines[0][0])) + delta_time
            ciclo = 0
            
            while True:
                
                for i in range(10):
                    
                    url = 'https://api.binance.com/api/v1/klines?symbol='+pair+'&interval=1m&startTime='+str(start_time)
                    
                    try:
                        
                        response = requests.get(url)
                        
                        new_klines = response.json()
                        
                        num_requests+= 1
                        
                        break

                    except Exception as error:
                        
                        print('Comunicação com a binance falhou no cliclo ',ciclo,', tentativa ',i,'. Erro: ', error) #Na verdade enviar para destino apropriado

                        time.sleep(5)

                if (new_klines):
                    
                    if (len(new_klines) < 500): #Chegou no mais recente
                        
                        print('dado mais atual, este foi o último ciclo')
                        
                        new_klines = new_klines[:(len(new_klines)-1)]
                        
                    db_save_kline_status = db_save_kline(pair,new_klines)
                    
                    if (db_save_kline_status == 'done'):
                        
                        start_time = start_time + delta_time
                        
                        print('New-kline gravada no banco no ciclo: ',ciclo)
                            
                    if (len(new_klines) < 500): 

                        break

                    if (len(new_klines) > 500): #Alguma anomalia.

                        print('ATENÇÃO, MAIS DE 500 AMOSTRAS')
                        break

                print ('Número de requests: ', num_requests)

                if(num_requests > int(max_requests)):

                    print('número máximo de requests atingido, dormindo 1 min')
                    num_requests = 0
                    time.sleep(60)
                    
                ciclo+=1
                    
        else:

            print('Comunicação com o banco falhou na entrada')
            print(' ')

        #Atualiza, na tabela "getdata_pairs", os 'historical' dos pares "absent", de "building" para "full"
        db_update_status = db_update_pair_table(pair,'full')
        print ('Atualizando par ', pair, ' para full. Status = ',db_update_status)
        print(' ')
    
    pid = 23
    return pid

# %%
pid = get_historical_data('BTCUSDT',500)
# Out:
# Atualizando par  BTCUSDT  para buiding. Status =  done
#
# entrada ok, na tentativa:  0
#
# Oldest request gravada no banco
#
# New-kline gravada no banco no ciclo:  0
# Número de requests:  2
# New-kline gravada no banco no ciclo:  1
# Número de requests:  3
# New-kline gravada no banco no ciclo:  2
# Número de requests:  4
# New-kline gravada no banco no ciclo:  3
# Número de requests:  5
# New-kline gravada no banco no ciclo:  4
# Número de requests:  6
# New-kline gravada no banco no ciclo:  5
# Número de requests:  7
# New-kline gravada no banco no ciclo:  6
# Número de requests:  8
# New-kline gravada no banco no ciclo:  7
# Número de requests:  9
# New-kline gravada no banco no ciclo:  8
# Número de requests:  10
# New-kline gravada no banco no ciclo:  9
# Número de requests:  11
# New-kline gravada no banco no ciclo:  10
# Número de requests:  12
# New-kline gravada no banco no ciclo:  11
# Número de requests:  13
# New-kline gravada no banco no ciclo:  12
# Número de requests:  14
# New-kline gravada no banco no ciclo:  13
# Número de requests:  15
# New-kline gravada no banco no ciclo:  14
# Número de requests:  16
# New-kline gravada no banco no ciclo:  15
# Número de requests:  17
# New-kline gravada no banco no ciclo:  16
# Número de requests:  18
# New-kline gravada no banco no ciclo:  17
# Número de requests:  19
# New-kline gravada no banco no ciclo:  18
# Número de requests:  20
# New-kline gravada no banco no ciclo:  19
# Número de requests:  21
# New-kline gravada no banco no ciclo:  20
# Número de requests:  22
# New-kline gravada no banco no ciclo:  21
# Número de requests:  23
# New-kline gravada no banco no ciclo:  22
# Número de requests:  24
# New-kline gravada no banco no ciclo:  23
# Número de requests:  25
# New-kline gravada no banco no ciclo:  24
# Número de requests:  26
# New-kline gravada no banco no ciclo:  25
# Número de requests:  27
# New-kline gravada no banco no ciclo:  26
# Número de requests:  28
# New-kline gravada no banco no ciclo:  27
# Número de requests:  29
# New-kline gravada no banco no ciclo:  28
# Número de requests:  30
# New-kline gravada no banco no ciclo:  29
# Número de requests:  31
# New-kline gravada no banco no ciclo:  30
# Número de requests:  32
# New-kline gravada no banco no ciclo:  31
# Número de requests:  33
# New-kline gravada no banco no ciclo:  32
# Número de requests:  34
# New-kline gravada no banco no ciclo:  33
# Número de requests:  35
# New-kline gravada no banco no ciclo:  34
# Número de requests:  36
# New-kline gravada no banco no ciclo:  35
# Número de requests:  37
# New-kline gravada no banco no ciclo:  36
# Número de requests:  38
# New-kline gravada no banco no ciclo:  37
# Número de requests:  39
# New-kline gravada no banco no ciclo:  38
# Número de requests:  40
# New-kline gravada no banco no ciclo:  39
# Número de requests:  41
# New-kline gravada no banco no ciclo:  40
# Número de requests:  42
# New-kline gravada no banco no ciclo:  41
# Número de requests:  43
# New-kline gravada no banco no ciclo:  42
# Número de requests:  44
# New-kline gravada no banco no ciclo:  43
# Número de requests:  45
# New-kline gravada no banco no ciclo:  44
# Número de requests:  46
# New-kline gravada no banco no ciclo:  45
# Número de requests:  47
# New-kline gravada no banco no ciclo:  46
# Número de requests:  48
# New-kline gravada no banco no ciclo:  47
# Número de requests:  49
# New-kline gravada no banco no ciclo:  48
# Número de requests:  50
# New-kline gravada no banco no ciclo:  49
# Número de requests:  51
# New-kline gravada no banco no ciclo:  50
# Número de requests:  52
# New-kline gravada no banco no ciclo:  51
# Número de requests:  53
# New-kline gravada no banco no ciclo:  52
# Número de requests:  54
# New-kline gravada no banco no ciclo:  53
# Número de requests:  55
# New-kline gravada no banco no ciclo:  54
# Número de requests:  56
# New-kline gravada no banco no ciclo:  55
# Número de requests:  57
# New-kline gravada no banco no ciclo:  56
# Número de requests:  58
# New-kline gravada no banco no ciclo:  57
# Número de requests:  59
# New-kline gravada no banco no ciclo:  58
# Número de requests:  60
# New-kline gravada no banco no ciclo:  59
# Número de requests:  61
# New-kline gravada no banco no ciclo:  60
# Número de requests:  62
# New-kline gravada no banco no ciclo:  61
# Número de requests:  63
# New-kline gravada no banco no ciclo:  62
# Número de requests:  64
# New-kline gravada no banco no ciclo:  63
# Número de requests:  65
# New-kline gravada no banco no ciclo:  64
# Número de requests:  66
# New-kline gravada no banco no ciclo:  65
# Número de requests:  67
# New-kline gravada no banco no ciclo:  66
# Número de requests:  68
# New-kline gravada no banco no ciclo:  67
# Número de requests:  69
# New-kline gravada no banco no ciclo:  68
# Número de requests:  70
# New-kline gravada no banco no ciclo:  69
# Número de requests:  71
# New-kline gravada no banco no ciclo:  70
# Número de requests:  72
# New-kline gravada no banco no ciclo:  71
# Número de requests:  73
# New-kline gravada no banco no ciclo:  72
# Número de requests:  74
# New-kline gravada no banco no ciclo:  73
# Número de requests:  75
# New-kline gravada no banco no ciclo:  74
# Número de requests:  76
# New-kline gravada no banco no ciclo:  75
# Número de requests:  77
# New-kline gravada no banco no ciclo:  76
# Número de requests:  78
# New-kline gravada no banco no ciclo:  77
# Número de requests:  79
# New-kline gravada no banco no ciclo:  78
# Número de requests:  80
# New-kline gravada no banco no ciclo:  79
# Número de requests:  81
# New-kline gravada no banco no ciclo:  80
# Número de requests:  82
# New-kline gravada no banco no ciclo:  81
# Número de requests:  83
# New-kline gravada no banco no ciclo:  82
# Número de requests:  84
# New-kline gravada no banco no ciclo:  83
# Número de requests:  85
# New-kline gravada no banco no ciclo:  84
# Número de requests:  86
# New-kline gravada no banco no ciclo:  85
# Número de requests:  87
# New-kline gravada no banco no ciclo:  86
# Número de requests:  88
# New-kline gravada no banco no ciclo:  87
# Número de requests:  89
# New-kline gravada no banco no ciclo:  88
# Número de requests:  90
# New-kline gravada no banco no ciclo:  89
# Número de requests:  91
# New-kline gravada no banco no ciclo:  90
# Número de requests:  92
# New-kline gravada no banco no ciclo:  91
# Número de requests:  93
# New-kline gravada no banco no ciclo:  92
# Número de requests:  94
# New-kline gravada no banco no ciclo:  93
# Número de requests:  95
# New-kline gravada no banco no ciclo:  94
# Número de requests:  96
# New-kline gravada no banco no ciclo:  95
# Número de requests:  97
# New-kline gravada no banco no ciclo:  96
# Número de requests:  98
# New-kline gravada no banco no ciclo:  97
# Número de requests:  99
# New-kline gravada no banco no ciclo:  98
# Número de requests:  100
# New-kline gravada no banco no ciclo:  99
# Número de requests:  101
# New-kline gravada no banco no ciclo:  100
# Número de requests:  102
# New-kline gravada no banco no ciclo:  101
# Número de requests:  103
# New-kline gravada no banco no ciclo:  102
# Número de requests:  104
# New-kline gravada no banco no ciclo:  103
# Número de requests:  105
# New-kline gravada no banco no ciclo:  104
# Número de requests:  106
# New-kline gravada no banco no ciclo:  105
# Número de requests:  107
# New-kline gravada no banco no ciclo:  106
# Número de requests:  108
# New-kline gravada no banco no ciclo:  107
# Número de requests:  109
# New-kline gravada no banco no ciclo:  108
# Número de requests:  110
# New-kline gravada no banco no ciclo:  109
# Número de requests:  111
# New-kline gravada no banco no ciclo:  110
# Número de requests:  112
# New-kline gravada no banco no ciclo:  111
# Número de requests:  113
# New-kline gravada no banco no ciclo:  112
# Número de requests:  114
# New-kline gravada no banco no ciclo:  113
# Número de requests:  115
# New-kline gravada no banco no ciclo:  114
# Número de requests:  116
# New-kline gravada no banco no ciclo:  115
# Número de requests:  117
# New-kline gravada no banco no ciclo:  116
# Número de requests:  118
# New-kline gravada no banco no ciclo:  117
# Número de requests:  119
# New-kline gravada no banco no ciclo:  118
# Número de requests:  120
# New-kline gravada no banco no ciclo:  119
# Número de requests:  121
# New-kline gravada no banco no ciclo:  120
# Número de requests:  122
# New-kline gravada no banco no ciclo:  121
# Número de requests:  123
# New-kline gravada no banco no ciclo:  122
# Número de requests:  124
# New-kline gravada no banco no ciclo:  123
# Número de requests:  125
# New-kline gravada no banco no ciclo:  124
# Número de requests:  126
# New-kline gravada no banco no ciclo:  125
# Número de requests:  127
# New-kline gravada no banco no ciclo:  126
# Número de requests:  128
# New-kline gravada no banco no ciclo:  127
# Número de requests:  129
# New-kline gravada no banco no ciclo:  128
# Número de requests:  130
# New-kline gravada no banco no ciclo:  129
# Número de requests:  131
# New-kline gravada no banco no ciclo:  130
# Número de requests:  132
# New-kline gravada no banco no ciclo:  131
# Número de requests:  133
# New-kline gravada no banco no ciclo:  132
# Número de requests:  134
# New-kline gravada no banco no ciclo:  133
# Número de requests:  135
# New-kline gravada no banco no ciclo:  134
# Número de requests:  136
# New-kline gravada no banco no ciclo:  135
# Número de requests:  137
# New-kline gravada no banco no ciclo:  136
# Número de requests:  138
# New-kline gravada no banco no ciclo:  137
# Número de requests:  139
# New-kline gravada no banco no ciclo:  138
# Número de requests:  140
# New-kline gravada no banco no ciclo:  139
# Número de requests:  141
# New-kline gravada no banco no ciclo:  140
# Número de requests:  142
# New-kline gravada no banco no ciclo:  141
# Número de requests:  143
# New-kline gravada no banco no ciclo:  142
# Número de requests:  144
# New-kline gravada no banco no ciclo:  143
# Número de requests:  145
# New-kline gravada no banco no ciclo:  144
# Número de requests:  146
# New-kline gravada no banco no ciclo:  145
# Número de requests:  147
# New-kline gravada no banco no ciclo:  146
# Número de requests:  148
# New-kline gravada no banco no ciclo:  147
# Número de requests:  149
# New-kline gravada no banco no ciclo:  148
# Número de requests:  150
# New-kline gravada no banco no ciclo:  149
# Número de requests:  151
# New-kline gravada no banco no ciclo:  150
# Número de requests:  152
# New-kline gravada no banco no ciclo:  151
# Número de requests:  153
# New-kline gravada no banco no ciclo:  152
# Número de requests:  154
# New-kline gravada no banco no ciclo:  153
# Número de requests:  155
# New-kline gravada no banco no ciclo:  154
# Número de requests:  156
# New-kline gravada no banco no ciclo:  155
# Número de requests:  157
# New-kline gravada no banco no ciclo:  156
# Número de requests:  158
# New-kline gravada no banco no ciclo:  157
# Número de requests:  159
# New-kline gravada no banco no ciclo:  158
# Número de requests:  160
# New-kline gravada no banco no ciclo:  159
# Número de requests:  161
# New-kline gravada no banco no ciclo:  160
# Número de requests:  162
# New-kline gravada no banco no ciclo:  161
# Número de requests:  163
# New-kline gravada no banco no ciclo:  162
# Número de requests:  164
# New-kline gravada no banco no ciclo:  163
# Número de requests:  165
# New-kline gravada no banco no ciclo:  164
# Número de requests:  166
# New-kline gravada no banco no ciclo:  165
# Número de requests:  167
# New-kline gravada no banco no ciclo:  166
# Número de requests:  168
# New-kline gravada no banco no ciclo:  167
# Número de requests:  169
# New-kline gravada no banco no ciclo:  168
# Número de requests:  170
# New-kline gravada no banco no ciclo:  169
# Número de requests:  171
# New-kline gravada no banco no ciclo:  170
# Número de requests:  172
# New-kline gravada no banco no ciclo:  171
# Número de requests:  173
# New-kline gravada no banco no ciclo:  172
# Número de requests:  174
# New-kline gravada no banco no ciclo:  173
# Número de requests:  175
# New-kline gravada no banco no ciclo:  174
# Número de requests:  176
# New-kline gravada no banco no ciclo:  175
# Número de requests:  177
# New-kline gravada no banco no ciclo:  176
# Número de requests:  178
# New-kline gravada no banco no ciclo:  177
# Número de requests:  179
# New-kline gravada no banco no ciclo:  178
# Número de requests:  180
# New-kline gravada no banco no ciclo:  179
# Número de requests:  181
# New-kline gravada no banco no ciclo:  180
# Número de requests:  182
# New-kline gravada no banco no ciclo:  181
# Número de requests:  183
# New-kline gravada no banco no ciclo:  182
# Número de requests:  184
# New-kline gravada no banco no ciclo:  183
# Número de requests:  185
# New-kline gravada no banco no ciclo:  184
# Número de requests:  186
# New-kline gravada no banco no ciclo:  185
# Número de requests:  187
# New-kline gravada no banco no ciclo:  186
# Número de requests:  188
# New-kline gravada no banco no ciclo:  187
# Número de requests:  189
# New-kline gravada no banco no ciclo:  188
# Número de requests:  190
# New-kline gravada no banco no ciclo:  189
# Número de requests:  191
# New-kline gravada no banco no ciclo:  190
# Número de requests:  192
# New-kline gravada no banco no ciclo:  191
# Número de requests:  193
# New-kline gravada no banco no ciclo:  192
# Número de requests:  194
# New-kline gravada no banco no ciclo:  193
# Número de requests:  195
# New-kline gravada no banco no ciclo:  194
# Número de requests:  196
# New-kline gravada no banco no ciclo:  195
# Número de requests:  197
# New-kline gravada no banco no ciclo:  196
# Número de requests:  198
# New-kline gravada no banco no ciclo:  197
# Número de requests:  199
# New-kline gravada no banco no ciclo:  198
# Número de requests:  200
# New-kline gravada no banco no ciclo:  199
# Número de requests:  201
# New-kline gravada no banco no ciclo:  200
# Número de requests:  202
# New-kline gravada no banco no ciclo:  201
# Número de requests:  203
# New-kline gravada no banco no ciclo:  202
# Número de requests:  204
# New-kline gravada no banco no ciclo:  203
# Número de requests:  205
# New-kline gravada no banco no ciclo:  204
# Número de requests:  206
# New-kline gravada no banco no ciclo:  205
# Número de requests:  207
# New-kline gravada no banco no ciclo:  206
# Número de requests:  208
# New-kline gravada no banco no ciclo:  207
# Número de requests:  209
# New-kline gravada no banco no ciclo:  208
# Número de requests:  210
# New-kline gravada no banco no ciclo:  209
# Número de requests:  211
# New-kline gravada no banco no ciclo:  210
# Número de requests:  212
# New-kline gravada no banco no ciclo:  211
# Número de requests:  213
# New-kline gravada no banco no ciclo:  212
# Número de requests:  214
# New-kline gravada no banco no ciclo:  213
# Número de requests:  215
# New-kline gravada no banco no ciclo:  214
# Número de requests:  216
# New-kline gravada no banco no ciclo:  215
# Número de requests:  217
# New-kline gravada no banco no ciclo:  216
# Número de requests:  218
# New-kline gravada no banco no ciclo:  217
# Número de requests:  219
# New-kline gravada no banco no ciclo:  218
# Número de requests:  220
# New-kline gravada no banco no ciclo:  219
# Número de requests:  221
# New-kline gravada no banco no ciclo:  220
# Número de requests:  222
# New-kline gravada no banco no ciclo:  221
# Número de requests:  223
# New-kline gravada no banco no ciclo:  222
# Número de requests:  224
# New-kline gravada no banco no ciclo:  223
# Número de requests:  225
# New-kline gravada no banco no ciclo:  224
# Número de requests:  226
# New-kline gravada no banco no ciclo:  225
# Número de requests:  227
# New-kline gravada no banco no ciclo:  226
# Número de requests:  228
# New-kline gravada no banco no ciclo:  227
# Número de requests:  229
# New-kline gravada no banco no ciclo:  228
# Número de requests:  230
# New-kline gravada no banco no ciclo:  229
# Número de requests:  231
# New-kline gravada no banco no ciclo:  230
# Número de requests:  232
# New-kline gravada no banco no ciclo:  231
# Número de requests:  233
# New-kline gravada no banco no ciclo:  232
# Número de requests:  234
# New-kline gravada no banco no ciclo:  233
# Número de requests:  235
# New-kline gravada no banco no ciclo:  234
# Número de requests:  236
# New-kline gravada no banco no ciclo:  235
# Número de requests:  237
# New-kline gravada no banco no ciclo:  236
# Número de requests:  238
# New-kline gravada no banco no ciclo:  237
# Número de requests:  239
# New-kline gravada no banco no ciclo:  238
# Número de requests:  240
# New-kline gravada no banco no ciclo:  239
# Número de requests:  241
# New-kline gravada no banco no ciclo:  240
# Número de requests:  242
# New-kline gravada no banco no ciclo:  241
# Número de requests:  243
# New-kline gravada no banco no ciclo:  242
# Número de requests:  244
# New-kline gravada no banco no ciclo:  243
# Número de requests:  245
# New-kline gravada no banco no ciclo:  244
# Número de requests:  246
# New-kline gravada no banco no ciclo:  245
# Número de requests:  247
# New-kline gravada no banco no ciclo:  246
# Número de requests:  248
# New-kline gravada no banco no ciclo:  247
# Número de requests:  249
# New-kline gravada no banco no ciclo:  248
# Número de requests:  250
# New-kline gravada no banco no ciclo:  249
# Número de requests:  251
# New-kline gravada no banco no ciclo:  250
# Número de requests:  252
# New-kline gravada no banco no ciclo:  251
# Número de requests:  253
# New-kline gravada no banco no ciclo:  252
# Número de requests:  254
# New-kline gravada no banco no ciclo:  253
# Número de requests:  255
# New-kline gravada no banco no ciclo:  254
# Número de requests:  256
# New-kline gravada no banco no ciclo:  255
# Número de requests:  257
# New-kline gravada no banco no ciclo:  256
# Número de requests:  258
# New-kline gravada no banco no ciclo:  257
# Número de requests:  259
# New-kline gravada no banco no ciclo:  258
# Número de requests:  260
# New-kline gravada no banco no ciclo:  259
# Número de requests:  261
# New-kline gravada no banco no ciclo:  260
# Número de requests:  262
# New-kline gravada no banco no ciclo:  261
# Número de requests:  263
# New-kline gravada no banco no ciclo:  262
# Número de requests:  264
# New-kline gravada no banco no ciclo:  263
# Número de requests:  265
# New-kline gravada no banco no ciclo:  264
# Número de requests:  266
# New-kline gravada no banco no ciclo:  265
# Número de requests:  267
# New-kline gravada no banco no ciclo:  266
# Número de requests:  268
# New-kline gravada no banco no ciclo:  267
# Número de requests:  269
# New-kline gravada no banco no ciclo:  268
# Número de requests:  270
# New-kline gravada no banco no ciclo:  269
# Número de requests:  271
# New-kline gravada no banco no ciclo:  270
# Número de requests:  272
# New-kline gravada no banco no ciclo:  271
# Número de requests:  273
# New-kline gravada no banco no ciclo:  272
# Número de requests:  274
# New-kline gravada no banco no ciclo:  273
# Número de requests:  275
# New-kline gravada no banco no ciclo:  274
# Número de requests:  276
# New-kline gravada no banco no ciclo:  275
# Número de requests:  277
# New-kline gravada no banco no ciclo:  276
# Número de requests:  278
# New-kline gravada no banco no ciclo:  277
# Número de requests:  279
# New-kline gravada no banco no ciclo:  278
# Número de requests:  280
# New-kline gravada no banco no ciclo:  279
# Número de requests:  281
# New-kline gravada no banco no ciclo:  280
# Número de requests:  282
# New-kline gravada no banco no ciclo:  281
# Número de requests:  283
# New-kline gravada no banco no ciclo:  282
# Número de requests:  284
# New-kline gravada no banco no ciclo:  283
# Número de requests:  285
# New-kline gravada no banco no ciclo:  284
# Número de requests:  286
# New-kline gravada no banco no ciclo:  285
# Número de requests:  287
# New-kline gravada no banco no ciclo:  286
# Número de requests:  288
# New-kline gravada no banco no ciclo:  287
# Número de requests:  289
# New-kline gravada no banco no ciclo:  288
# Número de requests:  290
# New-kline gravada no banco no ciclo:  289
# Número de requests:  291
# New-kline gravada no banco no ciclo:  290
# Número de requests:  292
# New-kline gravada no banco no ciclo:  291
# Número de requests:  293
# New-kline gravada no banco no ciclo:  292
# Número de requests:  294
# New-kline gravada no banco no ciclo:  293
# Número de requests:  295
# New-kline gravada no banco no ciclo:  294
# Número de requests:  296
# New-kline gravada no banco no ciclo:  295
# Número de requests:  297
# New-kline gravada no banco no ciclo:  296
# Número de requests:  298
# New-kline gravada no banco no ciclo:  297
# Número de requests:  299
# New-kline gravada no banco no ciclo:  298
# Número de requests:  300
# New-kline gravada no banco no ciclo:  299
# Número de requests:  301
# New-kline gravada no banco no ciclo:  300
# Número de requests:  302
# New-kline gravada no banco no ciclo:  301
# Número de requests:  303
# New-kline gravada no banco no ciclo:  302
# Número de requests:  304
# New-kline gravada no banco no ciclo:  303
# Número de requests:  305
# New-kline gravada no banco no ciclo:  304
# Número de requests:  306
# New-kline gravada no banco no ciclo:  305
# Número de requests:  307
# New-kline gravada no banco no ciclo:  306
# Número de requests:  308
# New-kline gravada no banco no ciclo:  307
# Número de requests:  309
# New-kline gravada no banco no ciclo:  308
# Número de requests:  310
# New-kline gravada no banco no ciclo:  309
# Número de requests:  311
# New-kline gravada no banco no ciclo:  310
# Número de requests:  312
# New-kline gravada no banco no ciclo:  311
# Número de requests:  313
# New-kline gravada no banco no ciclo:  312
# Número de requests:  314
# New-kline gravada no banco no ciclo:  313
# Número de requests:  315
# New-kline gravada no banco no ciclo:  314
# Número de requests:  316
# New-kline gravada no banco no ciclo:  315
# Número de requests:  317
# New-kline gravada no banco no ciclo:  316
# Número de requests:  318
# New-kline gravada no banco no ciclo:  317
# Número de requests:  319
# New-kline gravada no banco no ciclo:  318
# Número de requests:  320
# New-kline gravada no banco no ciclo:  319
# Número de requests:  321
# New-kline gravada no banco no ciclo:  320
# Número de requests:  322
# New-kline gravada no banco no ciclo:  321
# Número de requests:  323
# New-kline gravada no banco no ciclo:  322
# Número de requests:  324
# New-kline gravada no banco no ciclo:  323
# Número de requests:  325
# New-kline gravada no banco no ciclo:  324
# Número de requests:  326
# New-kline gravada no banco no ciclo:  325
# Número de requests:  327
# New-kline gravada no banco no ciclo:  326
# Número de requests:  328
# New-kline gravada no banco no ciclo:  327
# Número de requests:  329
# New-kline gravada no banco no ciclo:  328
# Número de requests:  330
# New-kline gravada no banco no ciclo:  329
# Número de requests:  331
# New-kline gravada no banco no ciclo:  330
# Número de requests:  332
# New-kline gravada no banco no ciclo:  331
# Número de requests:  333
# New-kline gravada no banco no ciclo:  332
# Número de requests:  334
# New-kline gravada no banco no ciclo:  333
# Número de requests:  335
# New-kline gravada no banco no ciclo:  334
# Número de requests:  336
# New-kline gravada no banco no ciclo:  335
# Número de requests:  337
# New-kline gravada no banco no ciclo:  336
# Número de requests:  338
# New-kline gravada no banco no ciclo:  337
# Número de requests:  339
# New-kline gravada no banco no ciclo:  338
# Número de requests:  340
# New-kline gravada no banco no ciclo:  339
# Número de requests:  341
# New-kline gravada no banco no ciclo:  340
# Número de requests:  342
# New-kline gravada no banco no ciclo:  341
# Número de requests:  343
# New-kline gravada no banco no ciclo:  342
# Número de requests:  344
# New-kline gravada no banco no ciclo:  343
# Número de requests:  345
# New-kline gravada no banco no ciclo:  344
# Número de requests:  346
# New-kline gravada no banco no ciclo:  345
# Número de requests:  347
# New-kline gravada no banco no ciclo:  346
# Número de requests:  348
# New-kline gravada no banco no ciclo:  347
# Número de requests:  349
# New-kline gravada no banco no ciclo:  348
# Número de requests:  350
# New-kline gravada no banco no ciclo:  349
# Número de requests:  351
# New-kline gravada no banco no ciclo:  350
# Número de requests:  352
# New-kline gravada no banco no ciclo:  351
# Número de requests:  353
# New-kline gravada no banco no ciclo:  352
# Número de requests:  354
# New-kline gravada no banco no ciclo:  353
# Número de requests:  355
# New-kline gravada no banco no ciclo:  354
# Número de requests:  356
# New-kline gravada no banco no ciclo:  355
# Número de requests:  357
# New-kline gravada no banco no ciclo:  356
# Número de requests:  358
# New-kline gravada no banco no ciclo:  357
# Número de requests:  359
# New-kline gravada no banco no ciclo:  358
# Número de requests:  360
# New-kline gravada no banco no ciclo:  359
# Número de requests:  361
# New-kline gravada no banco no ciclo:  360
# Número de requests:  362
# New-kline gravada no banco no ciclo:  361
# Número de requests:  363
# New-kline gravada no banco no ciclo:  362
# Número de requests:  364
# New-kline gravada no banco no ciclo:  363
# Número de requests:  365
# New-kline gravada no banco no ciclo:  364
# Número de requests:  366
# New-kline gravada no banco no ciclo:  365
# Número de requests:  367
# New-kline gravada no banco no ciclo:  366
# Número de requests:  368
# New-kline gravada no banco no ciclo:  367
# Número de requests:  369
# New-kline gravada no banco no ciclo:  368
# Número de requests:  370
# New-kline gravada no banco no ciclo:  369
# Número de requests:  371
# New-kline gravada no banco no ciclo:  370
# Número de requests:  372
# New-kline gravada no banco no ciclo:  371
# Número de requests:  373
# New-kline gravada no banco no ciclo:  372
# Número de requests:  374
# New-kline gravada no banco no ciclo:  373
# Número de requests:  375
# New-kline gravada no banco no ciclo:  374
# Número de requests:  376
# New-kline gravada no banco no ciclo:  375
# Número de requests:  377
# New-kline gravada no banco no ciclo:  376
# Número de requests:  378
# New-kline gravada no banco no ciclo:  377
# Número de requests:  379
# New-kline gravada no banco no ciclo:  378
# Número de requests:  380
# New-kline gravada no banco no ciclo:  379
# Número de requests:  381
# New-kline gravada no banco no ciclo:  380
# Número de requests:  382
# New-kline gravada no banco no ciclo:  381
# Número de requests:  383
# New-kline gravada no banco no ciclo:  382
# Número de requests:  384
# New-kline gravada no banco no ciclo:  383
# Número de requests:  385
# New-kline gravada no banco no ciclo:  384
# Número de requests:  386
# New-kline gravada no banco no ciclo:  385
# Número de requests:  387
# New-kline gravada no banco no ciclo:  386
# Número de requests:  388
# New-kline gravada no banco no ciclo:  387
# Número de requests:  389
# New-kline gravada no banco no ciclo:  388
# Número de requests:  390
# New-kline gravada no banco no ciclo:  389
# Número de requests:  391
# New-kline gravada no banco no ciclo:  390
# Número de requests:  392
# New-kline gravada no banco no ciclo:  391
# Número de requests:  393
# New-kline gravada no banco no ciclo:  392
# Número de requests:  394
# New-kline gravada no banco no ciclo:  393
# Número de requests:  395
# New-kline gravada no banco no ciclo:  394
# Número de requests:  396
# New-kline gravada no banco no ciclo:  395
# Número de requests:  397
# New-kline gravada no banco no ciclo:  396
# Número de requests:  398
# New-kline gravada no banco no ciclo:  397
# Número de requests:  399
# New-kline gravada no banco no ciclo:  398
# Número de requests:  400
# New-kline gravada no banco no ciclo:  399
# Número de requests:  401
# New-kline gravada no banco no ciclo:  400
# Número de requests:  402
# New-kline gravada no banco no ciclo:  401
# Número de requests:  403
# New-kline gravada no banco no ciclo:  402
# Número de requests:  404
# New-kline gravada no banco no ciclo:  403
# Número de requests:  405
# New-kline gravada no banco no ciclo:  404
# Número de requests:  406
# New-kline gravada no banco no ciclo:  405
# Número de requests:  407
# New-kline gravada no banco no ciclo:  406
# Número de requests:  408
# New-kline gravada no banco no ciclo:  407
# Número de requests:  409
# New-kline gravada no banco no ciclo:  408
# Número de requests:  410
# New-kline gravada no banco no ciclo:  409
# Número de requests:  411
# New-kline gravada no banco no ciclo:  410
# Número de requests:  412
# New-kline gravada no banco no ciclo:  411
# Número de requests:  413
# New-kline gravada no banco no ciclo:  412
# Número de requests:  414
# New-kline gravada no banco no ciclo:  413
# Número de requests:  415
# New-kline gravada no banco no ciclo:  414
# Número de requests:  416
# New-kline gravada no banco no ciclo:  415
# Número de requests:  417
# New-kline gravada no banco no ciclo:  416
# Número de requests:  418
# New-kline gravada no banco no ciclo:  417
# Número de requests:  419
# New-kline gravada no banco no ciclo:  418
# Número de requests:  420
# New-kline gravada no banco no ciclo:  419
# Número de requests:  421
# New-kline gravada no banco no ciclo:  420
# Número de requests:  422
# New-kline gravada no banco no ciclo:  421
# Número de requests:  423
# New-kline gravada no banco no ciclo:  422
# Número de requests:  424
# New-kline gravada no banco no ciclo:  423
# Número de requests:  425
# New-kline gravada no banco no ciclo:  424
# Número de requests:  426
# New-kline gravada no banco no ciclo:  425
# Número de requests:  427
# New-kline gravada no banco no ciclo:  426
# Número de requests:  428
# New-kline gravada no banco no ciclo:  427
# Número de requests:  429
# New-kline gravada no banco no ciclo:  428
# Número de requests:  430
# New-kline gravada no banco no ciclo:  429
# Número de requests:  431
# New-kline gravada no banco no ciclo:  430
# Número de requests:  432
# New-kline gravada no banco no ciclo:  431
# Número de requests:  433
# New-kline gravada no banco no ciclo:  432
# Número de requests:  434
# New-kline gravada no banco no ciclo:  433
# Número de requests:  435
# New-kline gravada no banco no ciclo:  434
# Número de requests:  436
# New-kline gravada no banco no ciclo:  435
# Número de requests:  437
# New-kline gravada no banco no ciclo:  436
# Número de requests:  438
# New-kline gravada no banco no ciclo:  437
# Número de requests:  439
# New-kline gravada no banco no ciclo:  438
# Número de requests:  440
# New-kline gravada no banco no ciclo:  439
# Número de requests:  441
# New-kline gravada no banco no ciclo:  440
# Número de requests:  442
# New-kline gravada no banco no ciclo:  441
# Número de requests:  443
# New-kline gravada no banco no ciclo:  442
# Número de requests:  444
# New-kline gravada no banco no ciclo:  443
# Número de requests:  445
# New-kline gravada no banco no ciclo:  444
# Número de requests:  446
# New-kline gravada no banco no ciclo:  445
# Número de requests:  447
# New-kline gravada no banco no ciclo:  446
# Número de requests:  448
# New-kline gravada no banco no ciclo:  447
# Número de requests:  449
# New-kline gravada no banco no ciclo:  448
# Número de requests:  450
# New-kline gravada no banco no ciclo:  449
# Número de requests:  451
# New-kline gravada no banco no ciclo:  450
# Número de requests:  452
# New-kline gravada no banco no ciclo:  451
# Número de requests:  453
# New-kline gravada no banco no ciclo:  452
# Número de requests:  454
# New-kline gravada no banco no ciclo:  453
# Número de requests:  455
# New-kline gravada no banco no ciclo:  454
# Número de requests:  456
# New-kline gravada no banco no ciclo:  455
# Número de requests:  457
# New-kline gravada no banco no ciclo:  456
# Número de requests:  458
# New-kline gravada no banco no ciclo:  457
# Número de requests:  459
# New-kline gravada no banco no ciclo:  458
# Número de requests:  460
# New-kline gravada no banco no ciclo:  459
# Número de requests:  461
# New-kline gravada no banco no ciclo:  460
# Número de requests:  462
# New-kline gravada no banco no ciclo:  461
# Número de requests:  463
# New-kline gravada no banco no ciclo:  462
# Número de requests:  464
# New-kline gravada no banco no ciclo:  463
# Número de requests:  465
# New-kline gravada no banco no ciclo:  464
# Número de requests:  466
# New-kline gravada no banco no ciclo:  465
# Número de requests:  467
# New-kline gravada no banco no ciclo:  466
# Número de requests:  468
# New-kline gravada no banco no ciclo:  467
# Número de requests:  469
# New-kline gravada no banco no ciclo:  468
# Número de requests:  470
# New-kline gravada no banco no ciclo:  469
# Número de requests:  471
# New-kline gravada no banco no ciclo:  470
# Número de requests:  472
# New-kline gravada no banco no ciclo:  471
# Número de requests:  473
# New-kline gravada no banco no ciclo:  472
# Número de requests:  474
# New-kline gravada no banco no ciclo:  473
# Número de requests:  475
# New-kline gravada no banco no ciclo:  474
# Número de requests:  476
# New-kline gravada no banco no ciclo:  475
# Número de requests:  477
# New-kline gravada no banco no ciclo:  476
# Número de requests:  478
# New-kline gravada no banco no ciclo:  477
# Número de requests:  479
# New-kline gravada no banco no ciclo:  478
# Número de requests:  480
# New-kline gravada no banco no ciclo:  479
# Número de requests:  481
# New-kline gravada no banco no ciclo:  480
# Número de requests:  482
# New-kline gravada no banco no ciclo:  481
# Número de requests:  483
# New-kline gravada no banco no ciclo:  482
# Número de requests:  484
# New-kline gravada no banco no ciclo:  483
# Número de requests:  485
# New-kline gravada no banco no ciclo:  484
# Número de requests:  486
# New-kline gravada no banco no ciclo:  485
# Número de requests:  487
# New-kline gravada no banco no ciclo:  486
# Número de requests:  488
# New-kline gravada no banco no ciclo:  487
# Número de requests:  489
# New-kline gravada no banco no ciclo:  488
# Número de requests:  490
# New-kline gravada no banco no ciclo:  489
# Número de requests:  491
# New-kline gravada no banco no ciclo:  490
# Número de requests:  492
# New-kline gravada no banco no ciclo:  491
# Número de requests:  493
# New-kline gravada no banco no ciclo:  492
# Número de requests:  494
# New-kline gravada no banco no ciclo:  493
# Número de requests:  495
# New-kline gravada no banco no ciclo:  494
# Número de requests:  496
# New-kline gravada no banco no ciclo:  495
# Número de requests:  497
# New-kline gravada no banco no ciclo:  496
# Número de requests:  498
# New-kline gravada no banco no ciclo:  497
# Número de requests:  499
# New-kline gravada no banco no ciclo:  498
# Número de requests:  500
# New-kline gravada no banco no ciclo:  499
# Número de requests:  501
# número máximo de requests atingido, dormindo 1 min
# New-kline gravada no banco no ciclo:  500
# Número de requests:  1
# New-kline gravada no banco no ciclo:  501
# Número de requests:  2
# New-kline gravada no banco no ciclo:  502
# Número de requests:  3
# New-kline gravada no banco no ciclo:  503
# Número de requests:  4
# New-kline gravada no banco no ciclo:  504
# Número de requests:  5
# New-kline gravada no banco no ciclo:  505
# Número de requests:  6
# New-kline gravada no banco no ciclo:  506
# Número de requests:  7
# New-kline gravada no banco no ciclo:  507
# Número de requests:  8
# New-kline gravada no banco no ciclo:  508
# Número de requests:  9
# New-kline gravada no banco no ciclo:  509
# Número de requests:  10
# New-kline gravada no banco no ciclo:  510
# Número de requests:  11
# New-kline gravada no banco no ciclo:  511
# Número de requests:  12
# New-kline gravada no banco no ciclo:  512
# Número de requests:  13
# New-kline gravada no banco no ciclo:  513
# Número de requests:  14
# New-kline gravada no banco no ciclo:  514
# Número de requests:  15
# New-kline gravada no banco no ciclo:  515
# Número de requests:  16
# New-kline gravada no banco no ciclo:  516
# Número de requests:  17
# New-kline gravada no banco no ciclo:  517
# Número de requests:  18
# New-kline gravada no banco no ciclo:  518
# Número de requests:  19
# New-kline gravada no banco no ciclo:  519
# Número de requests:  20
# New-kline gravada no banco no ciclo:  520
# Número de requests:  21
# New-kline gravada no banco no ciclo:  521
# Número de requests:  22
# New-kline gravada no banco no ciclo:  522
# Número de requests:  23
# New-kline gravada no banco no ciclo:  523
# Número de requests:  24
# New-kline gravada no banco no ciclo:  524
# Número de requests:  25
# New-kline gravada no banco no ciclo:  525
# Número de requests:  26
# New-kline gravada no banco no ciclo:  526
# Número de requests:  27
# New-kline gravada no banco no ciclo:  527
# Número de requests:  28
# New-kline gravada no banco no ciclo:  528
# Número de requests:  29
# New-kline gravada no banco no ciclo:  529
# Número de requests:  30
# New-kline gravada no banco no ciclo:  530
# Número de requests:  31
# New-kline gravada no banco no ciclo:  531
# Número de requests:  32
# New-kline gravada no banco no ciclo:  532
# Número de requests:  33
# New-kline gravada no banco no ciclo:  533
# Número de requests:  34
# New-kline gravada no banco no ciclo:  534
# Número de requests:  35
# New-kline gravada no banco no ciclo:  535
# Número de requests:  36
# New-kline gravada no banco no ciclo:  536
# Número de requests:  37
# New-kline gravada no banco no ciclo:  537
# Número de requests:  38
# New-kline gravada no banco no ciclo:  538
# Número de requests:  39
# New-kline gravada no banco no ciclo:  539
# Número de requests:  40
# New-kline gravada no banco no ciclo:  540
# Número de requests:  41
# New-kline gravada no banco no ciclo:  541
# Número de requests:  42
# New-kline gravada no banco no ciclo:  542
# Número de requests:  43
# New-kline gravada no banco no ciclo:  543
# Número de requests:  44
# New-kline gravada no banco no ciclo:  544
# Número de requests:  45
# New-kline gravada no banco no ciclo:  545
# Número de requests:  46
# New-kline gravada no banco no ciclo:  546
# Número de requests:  47
# New-kline gravada no banco no ciclo:  547
# Número de requests:  48
# New-kline gravada no banco no ciclo:  548
# Número de requests:  49
# New-kline gravada no banco no ciclo:  549
# Número de requests:  50
# New-kline gravada no banco no ciclo:  550
# Número de requests:  51
# New-kline gravada no banco no ciclo:  551
# Número de requests:  52
# New-kline gravada no banco no ciclo:  552
# Número de requests:  53
# New-kline gravada no banco no ciclo:  553
# Número de requests:  54
# New-kline gravada no banco no ciclo:  554
# Número de requests:  55
# New-kline gravada no banco no ciclo:  555
# Número de requests:  56
# New-kline gravada no banco no ciclo:  556
# Número de requests:  57
# New-kline gravada no banco no ciclo:  557
# Número de requests:  58
# New-kline gravada no banco no ciclo:  558
# Número de requests:  59
# New-kline gravada no banco no ciclo:  559
# Número de requests:  60
# New-kline gravada no banco no ciclo:  560
# Número de requests:  61
# New-kline gravada no banco no ciclo:  561
# Número de requests:  62
# New-kline gravada no banco no ciclo:  562
# Número de requests:  63
# New-kline gravada no banco no ciclo:  563
# Número de requests:  64
# New-kline gravada no banco no ciclo:  564
# Número de requests:  65
# New-kline gravada no banco no ciclo:  565
# Número de requests:  66
# New-kline gravada no banco no ciclo:  566
# Número de requests:  67
# New-kline gravada no banco no ciclo:  567
# Número de requests:  68
# New-kline gravada no banco no ciclo:  568
# Número de requests:  69
# New-kline gravada no banco no ciclo:  569
# Número de requests:  70
# New-kline gravada no banco no ciclo:  570
# Número de requests:  71
# New-kline gravada no banco no ciclo:  571
# Número de requests:  72
# New-kline gravada no banco no ciclo:  572
# Número de requests:  73
# New-kline gravada no banco no ciclo:  573
# Número de requests:  74
# New-kline gravada no banco no ciclo:  574
# Número de requests:  75
# New-kline gravada no banco no ciclo:  575
# Número de requests:  76
# New-kline gravada no banco no ciclo:  576
# Número de requests:  77
# New-kline gravada no banco no ciclo:  577
# Número de requests:  78
# New-kline gravada no banco no ciclo:  578
# Número de requests:  79
# New-kline gravada no banco no ciclo:  579
# Número de requests:  80
# New-kline gravada no banco no ciclo:  580
# Número de requests:  81
# New-kline gravada no banco no ciclo:  581
# Número de requests:  82
# New-kline gravada no banco no ciclo:  582
# Número de requests:  83
# New-kline gravada no banco no ciclo:  583
# Número de requests:  84
# New-kline gravada no banco no ciclo:  584
# Número de requests:  85
# New-kline gravada no banco no ciclo:  585
# Número de requests:  86
# New-kline gravada no banco no ciclo:  586
# Número de requests:  87
# New-kline gravada no banco no ciclo:  587
# Número de requests:  88
# New-kline gravada no banco no ciclo:  588
# Número de requests:  89
# New-kline gravada no banco no ciclo:  589
# Número de requests:  90
# New-kline gravada no banco no ciclo:  590
# Número de requests:  91
# New-kline gravada no banco no ciclo:  591
# Número de requests:  92
# New-kline gravada no banco no ciclo:  592
# Número de requests:  93
# New-kline gravada no banco no ciclo:  593
# Número de requests:  94
# New-kline gravada no banco no ciclo:  594
# Número de requests:  95
# New-kline gravada no banco no ciclo:  595
# Número de requests:  96
# New-kline gravada no banco no ciclo:  596
# Número de requests:  97
# New-kline gravada no banco no ciclo:  597
# Número de requests:  98
# New-kline gravada no banco no ciclo:  598
# Número de requests:  99
# New-kline gravada no banco no ciclo:  599
# Número de requests:  100
# New-kline gravada no banco no ciclo:  600
# Número de requests:  101
# New-kline gravada no banco no ciclo:  601
# Número de requests:  102
# New-kline gravada no banco no ciclo:  602
# Número de requests:  103
# New-kline gravada no banco no ciclo:  603
# Número de requests:  104
# New-kline gravada no banco no ciclo:  604
# Número de requests:  105
# New-kline gravada no banco no ciclo:  605
# Número de requests:  106
# New-kline gravada no banco no ciclo:  606
# Número de requests:  107
# New-kline gravada no banco no ciclo:  607
# Número de requests:  108
# New-kline gravada no banco no ciclo:  608
# Número de requests:  109
# New-kline gravada no banco no ciclo:  609
# Número de requests:  110
# New-kline gravada no banco no ciclo:  610
# Número de requests:  111
# New-kline gravada no banco no ciclo:  611
# Número de requests:  112
# New-kline gravada no banco no ciclo:  612
# Número de requests:  113
# New-kline gravada no banco no ciclo:  613
# Número de requests:  114
# New-kline gravada no banco no ciclo:  614
# Número de requests:  115
# New-kline gravada no banco no ciclo:  615
# Número de requests:  116
# New-kline gravada no banco no ciclo:  616
# Número de requests:  117
# New-kline gravada no banco no ciclo:  617
# Número de requests:  118
# New-kline gravada no banco no ciclo:  618
# Número de requests:  119
# New-kline gravada no banco no ciclo:  619
# Número de requests:  120
# New-kline gravada no banco no ciclo:  620
# Número de requests:  121
# New-kline gravada no banco no ciclo:  621
# Número de requests:  122
# New-kline gravada no banco no ciclo:  622
# Número de requests:  123
# New-kline gravada no banco no ciclo:  623
# Número de requests:  124
# New-kline gravada no banco no ciclo:  624
# Número de requests:  125
# New-kline gravada no banco no ciclo:  625
# Número de requests:  126
# New-kline gravada no banco no ciclo:  626
# Número de requests:  127
# New-kline gravada no banco no ciclo:  627
# Número de requests:  128
# New-kline gravada no banco no ciclo:  628
# Número de requests:  129
# New-kline gravada no banco no ciclo:  629
# Número de requests:  130
# New-kline gravada no banco no ciclo:  630
# Número de requests:  131
# New-kline gravada no banco no ciclo:  631
# Número de requests:  132
# New-kline gravada no banco no ciclo:  632
# Número de requests:  133
# New-kline gravada no banco no ciclo:  633
# Número de requests:  134
# New-kline gravada no banco no ciclo:  634
# Número de requests:  135
# New-kline gravada no banco no ciclo:  635
# Número de requests:  136
# New-kline gravada no banco no ciclo:  636
# Número de requests:  137
# New-kline gravada no banco no ciclo:  637
# Número de requests:  138
# New-kline gravada no banco no ciclo:  638
# Número de requests:  139
# New-kline gravada no banco no ciclo:  639
# Número de requests:  140
# New-kline gravada no banco no ciclo:  640
# Número de requests:  141
# New-kline gravada no banco no ciclo:  641
# Número de requests:  142
# New-kline gravada no banco no ciclo:  642
# Número de requests:  143
# New-kline gravada no banco no ciclo:  643
# Número de requests:  144
# New-kline gravada no banco no ciclo:  644
# Número de requests:  145
# New-kline gravada no banco no ciclo:  645
# Número de requests:  146
# New-kline gravada no banco no ciclo:  646
# Número de requests:  147
# New-kline gravada no banco no ciclo:  647
# Número de requests:  148
# New-kline gravada no banco no ciclo:  648
# Número de requests:  149
# New-kline gravada no banco no ciclo:  649
# Número de requests:  150
# New-kline gravada no banco no ciclo:  650
# Número de requests:  151
# New-kline gravada no banco no ciclo:  651
# Número de requests:  152
# New-kline gravada no banco no ciclo:  652
# Número de requests:  153
# New-kline gravada no banco no ciclo:  653
# Número de requests:  154
# New-kline gravada no banco no ciclo:  654
# Número de requests:  155
# New-kline gravada no banco no ciclo:  655
# Número de requests:  156
# New-kline gravada no banco no ciclo:  656
# Número de requests:  157
# New-kline gravada no banco no ciclo:  657
# Número de requests:  158
# New-kline gravada no banco no ciclo:  658
# Número de requests:  159
# New-kline gravada no banco no ciclo:  659
# Número de requests:  160
# New-kline gravada no banco no ciclo:  660
# Número de requests:  161
# New-kline gravada no banco no ciclo:  661
# Número de requests:  162
# New-kline gravada no banco no ciclo:  662
# Número de requests:  163
# New-kline gravada no banco no ciclo:  663
# Número de requests:  164
# New-kline gravada no banco no ciclo:  664
# Número de requests:  165
# New-kline gravada no banco no ciclo:  665
# Número de requests:  166
# New-kline gravada no banco no ciclo:  666
# Número de requests:  167
# New-kline gravada no banco no ciclo:  667
# Número de requests:  168
# New-kline gravada no banco no ciclo:  668
# Número de requests:  169
# New-kline gravada no banco no ciclo:  669
# Número de requests:  170
# New-kline gravada no banco no ciclo:  670
# Número de requests:  171
# New-kline gravada no banco no ciclo:  671
# Número de requests:  172
# New-kline gravada no banco no ciclo:  672
# Número de requests:  173
# New-kline gravada no banco no ciclo:  673
# Número de requests:  174
# New-kline gravada no banco no ciclo:  674
# Número de requests:  175
# New-kline gravada no banco no ciclo:  675
# Número de requests:  176
# New-kline gravada no banco no ciclo:  676
# Número de requests:  177
# New-kline gravada no banco no ciclo:  677
# Número de requests:  178
# New-kline gravada no banco no ciclo:  678
# Número de requests:  179
# New-kline gravada no banco no ciclo:  679
# Número de requests:  180
# New-kline gravada no banco no ciclo:  680
# Número de requests:  181
# New-kline gravada no banco no ciclo:  681
# Número de requests:  182
# New-kline gravada no banco no ciclo:  682
# Número de requests:  183
# New-kline gravada no banco no ciclo:  683
# Número de requests:  184
# New-kline gravada no banco no ciclo:  684
# Número de requests:  185
# New-kline gravada no banco no ciclo:  685
# Número de requests:  186
# New-kline gravada no banco no ciclo:  686
# Número de requests:  187
# New-kline gravada no banco no ciclo:  687
# Número de requests:  188
# New-kline gravada no banco no ciclo:  688
# Número de requests:  189
# New-kline gravada no banco no ciclo:  689
# Número de requests:  190
# New-kline gravada no banco no ciclo:  690
# Número de requests:  191
# New-kline gravada no banco no ciclo:  691
# Número de requests:  192
# New-kline gravada no banco no ciclo:  692
# Número de requests:  193
# New-kline gravada no banco no ciclo:  693
# Número de requests:  194
# New-kline gravada no banco no ciclo:  694
# Número de requests:  195
# New-kline gravada no banco no ciclo:  695
# Número de requests:  196
# New-kline gravada no banco no ciclo:  696
# Número de requests:  197
# New-kline gravada no banco no ciclo:  697
# Número de requests:  198
# New-kline gravada no banco no ciclo:  698
# Número de requests:  199
# New-kline gravada no banco no ciclo:  699
# Número de requests:  200
# New-kline gravada no banco no ciclo:  700
# Número de requests:  201
# New-kline gravada no banco no ciclo:  701
# Número de requests:  202
# New-kline gravada no banco no ciclo:  702
# Número de requests:  203
# New-kline gravada no banco no ciclo:  703
# Número de requests:  204
# New-kline gravada no banco no ciclo:  704
# Número de requests:  205
# New-kline gravada no banco no ciclo:  705
# Número de requests:  206
# New-kline gravada no banco no ciclo:  706
# Número de requests:  207
# New-kline gravada no banco no ciclo:  707
# Número de requests:  208
# New-kline gravada no banco no ciclo:  708
# Número de requests:  209
# New-kline gravada no banco no ciclo:  709
# Número de requests:  210
# New-kline gravada no banco no ciclo:  710
# Número de requests:  211
# New-kline gravada no banco no ciclo:  711
# Número de requests:  212
# New-kline gravada no banco no ciclo:  712
# Número de requests:  213
# New-kline gravada no banco no ciclo:  713
# Número de requests:  214
# New-kline gravada no banco no ciclo:  714
# Número de requests:  215
# New-kline gravada no banco no ciclo:  715
# Número de requests:  216
# New-kline gravada no banco no ciclo:  716
# Número de requests:  217
# New-kline gravada no banco no ciclo:  717
# Número de requests:  218
# New-kline gravada no banco no ciclo:  718
# ...
# New-kline gravada no banco no ciclo:  1642
# Número de requests:  141
# New-kline gravada no banco no ciclo:  1643
# Número de requests:  142
# New-kline gravada no banco no ciclo:  1644
# Número de requests:  143
# New-kline gravada no banco no ciclo:  1645
# Número de requests:  144
# New-kline gravada no banco no ciclo:  1646
# Número de requests:  145
# New-kline gravada no banco no ciclo:  1647
# Número de requests:  146
# New-kline gravada no banco no ciclo:  1648
# Número de requests:  147
# New-kline gravada no banco no ciclo:  1649
# Número de requests:  148
# New-kline gravada no banco no ciclo:  1650
# Número de requests:  149
# New-kline gravada no banco no ciclo:  1651
# Número de requests:  150
# New-kline gravada no banco no ciclo:  1652
# Número de requests:  151
# New-kline gravada no banco no ciclo:  1653
# Número de requests:  152
# New-kline gravada no banco no ciclo:  1654
# Número de requests:  153
# New-kline gravada no banco no ciclo:  1655
# Número de requests:  154
# New-kline gravada no banco no ciclo:  1656
# Número de requests:  155
# New-kline gravada no banco no ciclo:  1657
# Número de requests:  156
# New-kline gravada no banco no ciclo:  1658
# Número de requests:  157
# New-kline gravada no banco no ciclo:  1659
# Número de requests:  158
# New-kline gravada no banco no ciclo:  1660
# Número de requests:  159
# New-kline gravada no banco no ciclo:  1661
# Número de requests:  160
# New-kline gravada no banco no ciclo:  1662
# Número de requests:  161
# New-kline gravada no banco no ciclo:  1663
# Número de requests:  162
# New-kline gravada no banco no ciclo:  1664
# Número de requests:  163
# New-kline gravada no banco no ciclo:  1665
# Número de requests:  164
# New-kline gravada no banco no ciclo:  1666
# Número de requests:  165
# New-kline gravada no banco no ciclo:  1667
# Número de requests:  166
# New-kline gravada no banco no ciclo:  1668
# Número de requests:  167
# New-kline gravada no banco no ciclo:  1669
# Número de requests:  168
# New-kline gravada no banco no ciclo:  1670
# Número de requests:  169
# New-kline gravada no banco no ciclo:  1671
# Número de requests:  170
# New-kline gravada no banco no ciclo:  1672
# Número de requests:  171
# New-kline gravada no banco no ciclo:  1673
# Número de requests:  172
# New-kline gravada no banco no ciclo:  1674
# Número de requests:  173
# New-kline gravada no banco no ciclo:  1675
# Número de requests:  174
# New-kline gravada no banco no ciclo:  1676
# Número de requests:  175
# New-kline gravada no banco no ciclo:  1677
# Número de requests:  176
# New-kline gravada no banco no ciclo:  1678
# Número de requests:  177
# New-kline gravada no banco no ciclo:  1679
# Número de requests:  178
# New-kline gravada no banco no ciclo:  1680
# Número de requests:  179
# New-kline gravada no banco no ciclo:  1681
# Número de requests:  180
# New-kline gravada no banco no ciclo:  1682
# Número de requests:  181
# New-kline gravada no banco no ciclo:  1683
# Número de requests:  182
# New-kline gravada no banco no ciclo:  1684
# Número de requests:  183
# New-kline gravada no banco no ciclo:  1685
# Número de requests:  184
# New-kline gravada no banco no ciclo:  1686
# Número de requests:  185
# New-kline gravada no banco no ciclo:  1687
# Número de requests:  186
# New-kline gravada no banco no ciclo:  1688
# Número de requests:  187
# New-kline gravada no banco no ciclo:  1689
# Número de requests:  188
# New-kline gravada no banco no ciclo:  1690
# Número de requests:  189
# New-kline gravada no banco no ciclo:  1691
# Número de requests:  190
# New-kline gravada no banco no ciclo:  1692
# Número de requests:  191
# New-kline gravada no banco no ciclo:  1693
# Número de requests:  192
# New-kline gravada no banco no ciclo:  1694
# Número de requests:  193
# New-kline gravada no banco no ciclo:  1695
# Número de requests:  194
# New-kline gravada no banco no ciclo:  1696
# Número de requests:  195
# New-kline gravada no banco no ciclo:  1697
# Número de requests:  196
# New-kline gravada no banco no ciclo:  1698
# Número de requests:  197
# New-kline gravada no banco no ciclo:  1699
# Número de requests:  198
# New-kline gravada no banco no ciclo:  1700
# Número de requests:  199
# New-kline gravada no banco no ciclo:  1701
# Número de requests:  200
# New-kline gravada no banco no ciclo:  1702
# Número de requests:  201
# New-kline gravada no banco no ciclo:  1703
# Número de requests:  202
# New-kline gravada no banco no ciclo:  1704
# Número de requests:  203
# New-kline gravada no banco no ciclo:  1705
# Número de requests:  204
# New-kline gravada no banco no ciclo:  1706
# Número de requests:  205
# New-kline gravada no banco no ciclo:  1707
# Número de requests:  206
# New-kline gravada no banco no ciclo:  1708
# Número de requests:  207
# New-kline gravada no banco no ciclo:  1709
# Número de requests:  208
# New-kline gravada no banco no ciclo:  1710
# Número de requests:  209
# New-kline gravada no banco no ciclo:  1711
# Número de requests:  210
# New-kline gravada no banco no ciclo:  1712
# Número de requests:  211
# New-kline gravada no banco no ciclo:  1713
# Número de requests:  212
# New-kline gravada no banco no ciclo:  1714
# Número de requests:  213
# New-kline gravada no banco no ciclo:  1715
# Número de requests:  214
# New-kline gravada no banco no ciclo:  1716
# Número de requests:  215
# New-kline gravada no banco no ciclo:  1717
# Número de requests:  216
# New-kline gravada no banco no ciclo:  1718
# Número de requests:  217
# New-kline gravada no banco no ciclo:  1719
# Número de requests:  218
# New-kline gravada no banco no ciclo:  1720
# Número de requests:  219
# New-kline gravada no banco no ciclo:  1721
# Número de requests:  220
# New-kline gravada no banco no ciclo:  1722
# Número de requests:  221
# New-kline gravada no banco no ciclo:  1723
# Número de requests:  222
# New-kline gravada no banco no ciclo:  1724
# Número de requests:  223
# New-kline gravada no banco no ciclo:  1725
# Número de requests:  224
# New-kline gravada no banco no ciclo:  1726
# Número de requests:  225
# New-kline gravada no banco no ciclo:  1727
# Número de requests:  226
# New-kline gravada no banco no ciclo:  1728
# Número de requests:  227
# New-kline gravada no banco no ciclo:  1729
# Número de requests:  228
# New-kline gravada no banco no ciclo:  1730
# Número de requests:  229
# New-kline gravada no banco no ciclo:  1731
# Número de requests:  230
# New-kline gravada no banco no ciclo:  1732
# Número de requests:  231
# New-kline gravada no banco no ciclo:  1733
# Número de requests:  232
# New-kline gravada no banco no ciclo:  1734
# Número de requests:  233
# New-kline gravada no banco no ciclo:  1735
# Número de requests:  234
# New-kline gravada no banco no ciclo:  1736
# Número de requests:  235
# New-kline gravada no banco no ciclo:  1737
# Número de requests:  236
# New-kline gravada no banco no ciclo:  1738
# Número de requests:  237
# New-kline gravada no banco no ciclo:  1739
# Número de requests:  238
# New-kline gravada no banco no ciclo:  1740
# Número de requests:  239
# New-kline gravada no banco no ciclo:  1741
# Número de requests:  240
# New-kline gravada no banco no ciclo:  1742
# Número de requests:  241
# New-kline gravada no banco no ciclo:  1743
# Número de requests:  242
# New-kline gravada no banco no ciclo:  1744
# Número de requests:  243
# New-kline gravada no banco no ciclo:  1745
# Número de requests:  244
# New-kline gravada no banco no ciclo:  1746
# Número de requests:  245
# New-kline gravada no banco no ciclo:  1747
# Número de requests:  246
# New-kline gravada no banco no ciclo:  1748
# Número de requests:  247
# New-kline gravada no banco no ciclo:  1749
# Número de requests:  248
# New-kline gravada no banco no ciclo:  1750
# Número de requests:  249
# New-kline gravada no banco no ciclo:  1751
# Número de requests:  250
# New-kline gravada no banco no ciclo:  1752
# Número de requests:  251
# New-kline gravada no banco no ciclo:  1753
# Número de requests:  252
# New-kline gravada no banco no ciclo:  1754
# Número de requests:  253
# New-kline gravada no banco no ciclo:  1755
# Número de requests:  254
# New-kline gravada no banco no ciclo:  1756
# Número de requests:  255
# New-kline gravada no banco no ciclo:  1757
# Número de requests:  256
# New-kline gravada no banco no ciclo:  1758
# Número de requests:  257
# New-kline gravada no banco no ciclo:  1759
# Número de requests:  258
# New-kline gravada no banco no ciclo:  1760
# Número de requests:  259
# New-kline gravada no banco no ciclo:  1761
# Número de requests:  260
# New-kline gravada no banco no ciclo:  1762
# Número de requests:  261
# New-kline gravada no banco no ciclo:  1763
# Número de requests:  262
# New-kline gravada no banco no ciclo:  1764
# Número de requests:  263
# New-kline gravada no banco no ciclo:  1765
# Número de requests:  264
# New-kline gravada no banco no ciclo:  1766
# Número de requests:  265
# New-kline gravada no banco no ciclo:  1767
# Número de requests:  266
# New-kline gravada no banco no ciclo:  1768
# Número de requests:  267
# New-kline gravada no banco no ciclo:  1769
# Número de requests:  268
# New-kline gravada no banco no ciclo:  1770
# Número de requests:  269
# New-kline gravada no banco no ciclo:  1771
# Número de requests:  270
# New-kline gravada no banco no ciclo:  1772
# Número de requests:  271
# New-kline gravada no banco no ciclo:  1773
# Número de requests:  272
# New-kline gravada no banco no ciclo:  1774
# Número de requests:  273
# New-kline gravada no banco no ciclo:  1775
# Número de requests:  274
# New-kline gravada no banco no ciclo:  1776
# Número de requests:  275
# New-kline gravada no banco no ciclo:  1777
# Número de requests:  276
# New-kline gravada no banco no ciclo:  1778
# Número de requests:  277
# New-kline gravada no banco no ciclo:  1779
# Número de requests:  278
# New-kline gravada no banco no ciclo:  1780
# Número de requests:  279
# New-kline gravada no banco no ciclo:  1781
# Número de requests:  280
# New-kline gravada no banco no ciclo:  1782
# Número de requests:  281
# New-kline gravada no banco no ciclo:  1783
# Número de requests:  282
# New-kline gravada no banco no ciclo:  1784
# Número de requests:  283
# New-kline gravada no banco no ciclo:  1785
# Número de requests:  284
# New-kline gravada no banco no ciclo:  1786
# Número de requests:  285
# New-kline gravada no banco no ciclo:  1787
# Número de requests:  286
# New-kline gravada no banco no ciclo:  1788
# Número de requests:  287
# New-kline gravada no banco no ciclo:  1789
# Número de requests:  288
# New-kline gravada no banco no ciclo:  1790
# Número de requests:  289
# New-kline gravada no banco no ciclo:  1791
# Número de requests:  290
# New-kline gravada no banco no ciclo:  1792
# Número de requests:  291
# New-kline gravada no banco no ciclo:  1793
# Número de requests:  292
# New-kline gravada no banco no ciclo:  1794
# Número de requests:  293
# New-kline gravada no banco no ciclo:  1795
# Número de requests:  294
# New-kline gravada no banco no ciclo:  1796
# Número de requests:  295
# New-kline gravada no banco no ciclo:  1797
# Número de requests:  296
# New-kline gravada no banco no ciclo:  1798
# Número de requests:  297
# New-kline gravada no banco no ciclo:  1799
# Número de requests:  298
# New-kline gravada no banco no ciclo:  1800
# Número de requests:  299
# New-kline gravada no banco no ciclo:  1801
# Número de requests:  300
# New-kline gravada no banco no ciclo:  1802
# Número de requests:  301
# New-kline gravada no banco no ciclo:  1803
# Número de requests:  302
# New-kline gravada no banco no ciclo:  1804
# Número de requests:  303
# New-kline gravada no banco no ciclo:  1805
# Número de requests:  304
# New-kline gravada no banco no ciclo:  1806
# Número de requests:  305
# New-kline gravada no banco no ciclo:  1807
# Número de requests:  306
# New-kline gravada no banco no ciclo:  1808
# Número de requests:  307
# New-kline gravada no banco no ciclo:  1809
# Número de requests:  308
# New-kline gravada no banco no ciclo:  1810
# Número de requests:  309
# New-kline gravada no banco no ciclo:  1811
# Número de requests:  310
# New-kline gravada no banco no ciclo:  1812
# Número de requests:  311
# New-kline gravada no banco no ciclo:  1813
# Número de requests:  312
# New-kline gravada no banco no ciclo:  1814
# Número de requests:  313
# New-kline gravada no banco no ciclo:  1815
# Número de requests:  314
# New-kline gravada no banco no ciclo:  1816
# Número de requests:  315
# New-kline gravada no banco no ciclo:  1817
# Número de requests:  316
# New-kline gravada no banco no ciclo:  1818
# Número de requests:  317
# New-kline gravada no banco no ciclo:  1819
# Número de requests:  318
# New-kline gravada no banco no ciclo:  1820
# Número de requests:  319
# New-kline gravada no banco no ciclo:  1821
# Número de requests:  320
# New-kline gravada no banco no ciclo:  1822
# Número de requests:  321
# New-kline gravada no banco no ciclo:  1823
# Número de requests:  322
# New-kline gravada no banco no ciclo:  1824
# Número de requests:  323
# New-kline gravada no banco no ciclo:  1825
# Número de requests:  324
# New-kline gravada no banco no ciclo:  1826
# Número de requests:  325
# New-kline gravada no banco no ciclo:  1827
# Número de requests:  326
# New-kline gravada no banco no ciclo:  1828
# Número de requests:  327
# New-kline gravada no banco no ciclo:  1829
# Número de requests:  328
# New-kline gravada no banco no ciclo:  1830
# Número de requests:  329
# New-kline gravada no banco no ciclo:  1831
# Número de requests:  330
# New-kline gravada no banco no ciclo:  1832
# Número de requests:  331
# New-kline gravada no banco no ciclo:  1833
# Número de requests:  332
# New-kline gravada no banco no ciclo:  1834
# Número de requests:  333
# New-kline gravada no banco no ciclo:  1835
# Número de requests:  334
# New-kline gravada no banco no ciclo:  1836
# Número de requests:  335
# New-kline gravada no banco no ciclo:  1837
# Número de requests:  336
# New-kline gravada no banco no ciclo:  1838
# Número de requests:  337
# New-kline gravada no banco no ciclo:  1839
# Número de requests:  338
# New-kline gravada no banco no ciclo:  1840
# Número de requests:  339
# New-kline gravada no banco no ciclo:  1841
# Número de requests:  340
# New-kline gravada no banco no ciclo:  1842
# Número de requests:  341
# New-kline gravada no banco no ciclo:  1843
# Número de requests:  342
# New-kline gravada no banco no ciclo:  1844
# Número de requests:  343
# New-kline gravada no banco no ciclo:  1845
# Número de requests:  344
# New-kline gravada no banco no ciclo:  1846
# Número de requests:  345
# New-kline gravada no banco no ciclo:  1847
# Número de requests:  346
# New-kline gravada no banco no ciclo:  1848
# Número de requests:  347
# New-kline gravada no banco no ciclo:  1849
# Número de requests:  348
# New-kline gravada no banco no ciclo:  1850
# Número de requests:  349
# New-kline gravada no banco no ciclo:  1851
# Número de requests:  350
# New-kline gravada no banco no ciclo:  1852
# Número de requests:  351
# New-kline gravada no banco no ciclo:  1853
# Número de requests:  352
# New-kline gravada no banco no ciclo:  1854
# Número de requests:  353
# New-kline gravada no banco no ciclo:  1855
# Número de requests:  354
# New-kline gravada no banco no ciclo:  1856
# Número de requests:  355
# New-kline gravada no banco no ciclo:  1857
# Número de requests:  356
# New-kline gravada no banco no ciclo:  1858
# Número de requests:  357
# New-kline gravada no banco no ciclo:  1859
# Número de requests:  358
# New-kline gravada no banco no ciclo:  1860
# Número de requests:  359
# New-kline gravada no banco no ciclo:  1861
# Número de requests:  360
# New-kline gravada no banco no ciclo:  1862
# Número de requests:  361
# New-kline gravada no banco no ciclo:  1863
# Número de requests:  362
# New-kline gravada no banco no ciclo:  1864
# Número de requests:  363
# New-kline gravada no banco no ciclo:  1865
# Número de requests:  364
# New-kline gravada no banco no ciclo:  1866
# Número de requests:  365
# New-kline gravada no banco no ciclo:  1867
# Número de requests:  366
# New-kline gravada no banco no ciclo:  1868
# Número de requests:  367
# New-kline gravada no banco no ciclo:  1869
# Número de requests:  368
# New-kline gravada no banco no ciclo:  1870
# Número de requests:  369
# New-kline gravada no banco no ciclo:  1871
# Número de requests:  370
# New-kline gravada no banco no ciclo:  1872
# Número de requests:  371
# New-kline gravada no banco no ciclo:  1873
# Número de requests:  372
# New-kline gravada no banco no ciclo:  1874
# Número de requests:  373
# dado mais atual, este foi o último ciclo
# New-kline gravada no banco no ciclo:  1875
# Atualizando par  BTCUSDT  para full. Status =  done

# %%
url = 'https://api.binance.com/api/v1/klines?symbol=ETHBTC&interval=1m&startTime=1241893500000'

oldest_klines = requests.get(url)

# %%
oldest_klines.json()[0]

# %%
len(oldest_klines.json())
